# %%
import pandas as pd

df = pd.read_csv('transaction_data.csv', engine='python')

df = df.drop(['NumberOfItemsPurchased', 'CostPerItem', 'UserId', 'Country'], axis=1)
# df = df.drop(['ItemDescription', 'NumberOfItemsPurchased', 'CostPerItem', 'UserId', 'Country'], axis=1)

df = df.sort_values('TransactionId').reset_index(drop=True)

# 確保 ItemCode 至少包含4位數字
def check_stockcode(stockcode):
    digits = sum(c.isdigit() for c in stockcode)  # 計算數字的數量
    return digits >= 4

# 確保 ItemCode為string，並篩選符合條件的數據
df['ItemCode'] = df['ItemCode'].astype(str)
df = df[df['ItemCode'].apply(check_stockcode)]

# 截取 前四個字元
# df.loc[:, 'ItemCode'] = df['ItemCode'].apply(lambda x: str(x)[:4])  


df
# Out:
#          TransactionId               TransactionTime ItemCode  \
# 0              5900015  Mon Feb 12 04:26:00 IST 2018   477792
# 1              5900015  Mon Feb 12 04:26:00 IST 2018  1787583
# 2              5900015  Mon Feb 12 04:26:00 IST 2018  1492113
# 3              5900015  Mon Feb 12 04:26:00 IST 2018  1764609
# 4              5900015  Mon Feb 12 04:26:00 IST 2018  1772526
# ...                ...                           ...      ...
# 1083813        6397457  Wed Feb 20 08:50:00 IST 2019   473655
# 1083814        6397457  Wed Feb 20 08:50:00 IST 2019   475251
# 1083815        6397457  Wed Feb 20 08:50:00 IST 2019   474873
# 1083816        6397457  Wed Feb 20 08:50:00 IST 2019   475209
# 1083817        6397457  Wed Feb 20 08:50:00 IST 2019   477288
#
#                              ItemDescription
# 0               SET 7 BABUSHKA NESTING BOXES
# 1         WHITE HANGING HEART T-LIGHT HOLDER
# 2                        WHITE METAL LANTERN
# 3        KNITTED UNION FLAG HOT WATER BOTTLE
# 4             CREAM CUPID HEARTS COAT HANGER
# ...                                      ...
# 1083813            PLASTERS IN TIN STRONGMAN
# 1083814             CIRCUS PARADE LUNCH BOX
# 1083815          PACK OF 20 SPACEBOY NAPKINS
# 1083816                  SPACEBOY LUNCH BOX
# 1083817            ALARM CLOCK BAKELIKE PINK
#
# [1077926 rows x 4 columns]

# %%
transaction = df.groupby('TransactionId')['ItemCode'].apply(list).reset_index()

# 只保留至少購買 2 個不同商品的交易
transaction['ItemCode'] = transaction['ItemCode'].apply(lambda x: list(set(x)))  # 去重複
transaction = transaction[transaction['ItemCode'].apply(len) > 1].reset_index(drop=True)

transaction
# Out:
#        TransactionId                                           ItemCode
# 0            5900015  [477792, 1764609, 456330, 1772526, 1492113, 17...
# 1            5900026                                   [475272, 475293]
# 2            5900037  [477729, 456834, 457317, 475083, 477708, 47764...
# 3            5900048                   [481152, 481194, 482160, 481173]
# 4            5900070  [480900, 441735, 457611, 472332, 460173, 45620...
# ...              ...                                                ...
# 19934        6397413                                  [435225, 1785798]
# 19935        6397424                                  [437472, 1785798]
# 19936        6397435  [484764, 486045, 489888, 472101, 1783845, 1783...
# 19937        6397446                   [463281, 434385, 445557, 488775]
# 19938        6397457  [464898, 488355, 477288, 475209, 469707, 47367...
#
# [19939 rows x 2 columns]

# %%
import csv

with open("data_to_transaction.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(transaction['ItemCode'])

print(f"number of transaction: {len(transaction)}")
# Out:
# number of transaction: 19939

# %%
import pandas as pd

df = pd.read_csv('transaction_data.csv', engine='python')

# 嘗試將 ItemCode 轉為 int，若失敗則移除該行
df = df[pd.to_numeric(df['ItemCode'], errors='coerce').notna()]
df['ItemCode'] = df['ItemCode'].astype(int)

# 移除 ItemDescription 為 NaN 的行
df = df.dropna(subset=['ItemDescription'])

# ItemCode → ItemDescription 
item_lookup = df[['ItemCode', 'ItemDescription']].drop_duplicates().set_index('ItemCode')['ItemDescription'].to_dict()


def find_item_description(item_code):
    return item_lookup.get(int(item_code), "Unknown")

item_lookup
# Out:
# {465549: 'FAMILY ALBUM WHITE PICTURE FRAME',
#  482370: 'LONDON BUS COFFEE MUG',
#  490728: 'SET 12 COLOUR PENCILS DOLLY GIRL ',
#  459186: 'UNION JACK FLAG LUGGAGE TAG',
#  1733592: 'WASHROOM METAL SIGN',
#  1787247: 'check?',
#  471576: 'NATURAL SLATE CHALKBOARD LARGE ',
#  447867: 'SKULLS WRITING SET ',
#  1783845: 'MULTI COLOUR SILVER T-LIGHT HOLDER',
#  494802: 'SET OF 6 RIBBONS PERFECTLY PRETTY  ',
#  460215: 'John Lewis',
#  459669: 'WOODEN BOX OF DOMINOES',
#  486276: 'SET OF 5 MINI GROCERY MAGNETS',
#  435225: 'LUNCH BAG RED SPOTTY',
#  455868: 'FOLDING UMBRELLA CREAM POLKADOT',
#  477246: 'ALARM CLOCK BAKELIKE GREEN',
#  477036: 'CARD CIRCUS PARADE',
#  489594: 'VINTAGE CHRISTMAS TABLECLOTH',
#  1771938: 'SET OF 3 HEART COOKIE CUTTERS',
#  461622: 'PACK OF 12 SUKI TISSUES ',
#  476028: 'PINK BABY BUNTING',
#  434028: 'DISCO BALL CHRISTMAS DECORATION',
#  474726: 'check',
#  490329: 'ROLL WRAP VINTAGE CHRISTMAS',
#  443436: 'OWL DOORSTOP',
#  464751: 'FOOD CONTAINER SET 3 LOVE HEART ',
#  452844: 'PINK  HEART SHAPE LOVE BUCKET ',
#  485667: 'DOLLCRAFT GIRL NICOLE',
#  469392: 'LUNCH BOX WITH CUTLERY RETROSPOT ',
#  453348: 'RETROSPOT GIANT TUBE MATCHES',
#  482559: 'PANTRY WASHING UP BRUSH',
#  460656: 'RED RETROSPOT PICNIC BAG',
#  488019: 'SET OF 4 KNICK KNACK TINS POPPIES',
#  441735: 'SET/2 RED RETROSPOT TEA TOWELS ',
#  472647: 'MEMO BOARD RETROSPOT  DESIGN',
#  435204: 'RED RETROSPOT CHARLOTTE BAG',
#  436380: 'BLACK EAR MUFF HEADPHONES',
#  434973: 'found',
#  475839: 'LUNCH BOX I LOVE LONDON',
#  1784370: 'SINGLE HEART ZINC T-LIGHT HOLDER',
#  476007: 'damaged',
#  469875: 'AIRLINE BAG VINTAGE JET SET BROWN',
#  445452: 'PACK OF 72 RETROSPOT CAKE CASES',
#  440370: 'PINK FLORAL FELTCRAFT SHOULDER BAG',
#  1784832: '72 SWEETHEART FAIRY CAKE CASES',
#  456351: 'RED TOADSTOOL LED NIGHT LIGHT',
#  459963: 'MAN FLU METAL SIGN',
#  435288: 'LUNCH BAG CARS BLUE',
#  444759: 'damaged',
#  454818: 'GLASS  BEURRE DISH',
#  474873: 'PACK OF 20 SPACEBOY NAPKINS',
#  440538: '36 PENCILS TUBE SKULLS',
#  461664: 'PACK OF 12 PINK PAISLEY TISSUES ',
#  465738: 'VICTORIAN GLASS HANGING T-LIGHT',
#  490455: 'HOT WATER BOTTLE KEEP CALM',
#  492513: 'OVAL  MINI PORTRAIT FRAME',
#  488145: 'SET OF 3 REGENCY CAKE TINS',
#  476763: 'PINK CAT BOWL',
#  479955: 'FINE WICKER HEART ',
#  479157: 'CARD SUKI BIRTHDAY',
#  471765: 'HANGING METAL STAR LANTERN',
#  358911: 'found',
#  452319: 'damages?',
#  493563: 'PLAYING CARDS KEEP CALM & CARRY ON',
#  472017: 'WATERING CAN GARDEN MARKER',
#  452004: 'DOORMAT SPOTTY HOME SWEET HOME',
#  473256: 'MAGIC DRAWING SLATE PURDEY',
#  1732374: 'crushed ctn',
#  477162: 'SET OF 6 SPICE TINS PANTRY DESIGN',
#  466452: 'FOUR HOOK  WHITE LOVEBIRDS',
#  357063: 'BROCADE RING PURSE ',
#  478989: 'SET OF 6 T-LIGHTS SANTA',
#  1765638: 'SET/4 WHITE RETRO STORAGE CUBES ',
#  466137: 'POPCORN HOLDER',
#  489699: "BOX OF 6 MINI 50'S CRACKERS",
#  1787079: 'JUMBO BAG STRAWBERRY',
#  472332: 'MINI PAINT SET VINTAGE ',
#  479031: 'SET OF 6 T-LIGHTS CACTI ',
#  462588: 'PENNY FARTHING BIRTHDAY CARD',
#  483588: 'DOORKNOB CRACKED GLAZE BLUE',
#  461496: 'PACK OF 60 MUSHROOM CAKE CASES',
#  474789: 'PENS ASSORTED SPACEBALL',
#  1733907: 'AIRLINE LOUNGE,METAL SIGN',
#  471870: 'HEART OF WICKER LARGE',
#  439194: 'SET/5 RED SPOTTY LID GLASS BOWLS',
#  1787583: 'wrongly marked carton 22804',
#  489531: 'VINTAGE CHRISTMAS STOCKING ',
#  470631: 'JUMBO SHOPPER VINTAGE RED PAISLEY',
#  473109: 'MAGIC DRAWING SLATE GO TO THE FAIR ',
#  482055: '36 FOIL STAR CAKE CASES ',
#  475734: 'DELUXE SEWING KIT ',
#  461643: 'PACK OF 12 BLUE PAISLEY TISSUES ',
#  469581: 'GLASS JAR DAISY FRESH COTTON WOOL',
#  471891: 'TV DINNER TRAY AIR HOSTESS ',
#  435855: 'BLUE PAISLEY POCKET BOOK',
#  442680: 'SET/20 RED RETROSPOT PAPER NAPKINS ',
#  457989: 'CHRISTMAS HANGING TREE WITH BELL',
#  464898: 'BAKING SET 9 PIECE RETROSPOT ',
#  445473: 'PACK OF 72 SKULL CAKE CASES',
#  481047: 'PACK OF 20 NAPKINS PANTRY DESIGN',
#  474138: 'lost',
#  487326: 'LUNCH BAG APPLE DESIGN',
#  474999: 'SET OF 6 SOLDIER SKITTLES',
#  477855: 'SMALL PURPLE BABUSHKA NOTEBOOK ',
#  463827: 'Amazon',
#  435393: 'GOLD MINI TAPE MEASURE ',
#  457464: 'SHOE SHINE BOX ',
#  445347: 'SKULL AND CROSSBONES  GARLAND ',
#  490245: ' DOLLY GIRL BEAKER',
#  494949: 'TRADTIONAL ALPHABET STAMP SET',
#  463491: 'SMALL WHITE RETROSPOT MUG IN BOX ',
#  482958: 'TRAVEL CARD WALLET KEEP CALM',
#  445410: 'SET OF 72 RETROSPOT PAPER  DOILIES',
#  445536: 'SET 3 RETROSPOT TEA,COFFEE,SUGAR',
#  463386: 'LOVE HEART TRINKET POT',
#  457254: 'DECORATIVE CATS BATHROOM BOTTLE',
#  478317: 'GLASS BELL JAR LARGE',
#  444234: 'RED RETROSPOT OVEN GLOVE ',
#  486024: 'ZINC T-LIGHT HOLDER STARS SMALL',
#  472311: 'PACK OF 12 COLOURED PENCILS',
#  477225: 'ALARM CLOCK BAKELIKE CHOCOLATE',
#  1764672: 'CHARLIE + LOLA RED HOT WATER BOTTLE',
#  1764630: 'ENGLISH ROSE HOT WATER BOTTLE',
#  478464: 'damages',
#  483315: 'CORDIAL GLASS JUG',
#  452130: 'DAIRY MAID TOASTRACK',
#  490476: 'LOVE HOT WATER BOTTLE',
#  484029: 'RECYCLED ACAPULCO MAT RED',
#  470883: 'faulty',
#  999390: 'check',
#  447993: 'CLASSIC WHITE FRAME',
#  451101: 'FAWN BLUE HOT WATER BOTTLE',
#  489006: 'BLUE VINTAGE SPOT BEAKER',
#  488964: 'DOORMAT KEEP CALM AND COME IN',
#  435267: 'LUNCH BAG  BLACK SKULL.',
#  461748: 'PACK OF 6 SKULL PAPER PLATES',
#  489720: "GIANT 50'S CHRISTMAS CRACKER",
#  461580: 'PACK OF 12 RED RETROSPOT TISSUES ',
#  486759: "CLOCK MAGNET MUM'S KITCHEN",
#  455322: '?display?',
#  1780905: 'CREAM CLIMBING HYDRANGA ART FLOWER',
#  482916: 'TRAVEL CARD WALLET VINTAGE TICKET',
#  446418: '?',
#  445872: 'STRAWBERRY CERAMIC TRINKET POT',
#  -1: 'PADS TO MATCH ALL CUSHIONS',
#  460488: 'JUMBO BAG SCANDINAVIAN PAISLEY',
#  1012074: 'DOORMAT HEARTS',
#  487074: 'GYMKHANNA TREASURE BOOK BOX',
#  1788906: 'BUNNY EGG GARLAND',
#  474474: 'CHRISTMAS GINGHAM TREE',
#  490791: 'SET 36 COLOUR PENCILS SPACEBOY ',
#  1784748: '?',
#  470862: 'TOOTHPASTE TUBE PEN',
#  472269: 'PACK OF 12 TRADITIONAL CRAYONS',
#  459648: 'check',
#  315756: 'ASSORTED COLOURS SILK FAN',
#  465213: 'ANGEL DECORATION STARS ON DRESS',
#  456036: 'BOYS VINTAGE TIN SEASIDE BUCKET',
#  1501017: 'COLOUR GLASS. STAR T-LIGHT HOLDER',
#  446460: 'FIRST AID TIN',
#  459417: 'HOME SWEET HOME MUG',
#  489321: 'GARDENERS KNEELING PAD KEEP CALM ',
#  491190: 'DOLLY GIRL MINI RUCKSACK',
#  486318: 'SET OF 5 LUCKY CAT MAGNETS ',
#  493353: 'VINTAGE DOILY TRAVEL SEWING KIT',
#  465024: 'CHRISTMAS CRAFT LITTLE FRIENDS',
#  452277: '?',
#  467334: 'FELT TOADSTOOL LARGE',
#  473319: 'MINI JIGSAW DOLLY GIRL',
#  435729: 'ASSORTED COLOUR MINI CASES',
#  1734222: '??',
#  998886: 'reverse previous adjustment',
#  459396: 'POTTERING MUG',
#  492849: 'CARD HOLDER LOVE BIRD SMALL',
#  479199: 'BIRTHDAY CARD, RETRO SPOT',
#  1732122: 'WOODEN PICTURE FRAME WHITE FINISH',
#  470064: 'LUNCH BAG PINK POLKADOT',
#  444486: '?',
#  460362: 'UNION STRIPE WITH FRINGE  HAMMOCK',
#  489342: 'KNEELING MAT HOUSEWORK  DESIGN',
#  494970: 'TRADITIONAL PICK UP STICKS GAME ',
#  464919: 'amazon',
#  462483: 'EMPIRE BIRTHDAY CARD',
#  1519371: 'SET/6 PINK  BUTTERFLY T-LIGHTS',
#  1890063: 'ROSE COLOUR PAIR HEART HAIR SLIDES',
#  457590: 'VINTAGE SNAP CARDS',
#  488754: 'STAR T-LIGHT HOLDER WILLIE WINKIE',
#  475104: 'IVORY KITCHEN SCALES',
#  316176: 'EDWARDIAN PARASOL PINK',
#  482349: 'HOMEMADE JAM SCENTED CANDLES',
#  479871: 'SET 20 NAPKINS FAIRY CAKES DESIGN ',
#  470442: 'MAGNETS PACK OF 4 VINTAGE COLLAGE',
#  476868: 'WRAP DOLLY GIRL',
#  744891: 'SET OF 3 BIRD LIGHT PINK FEATHER ',
#  487200: 'mailout ',
#  485100: 'SILVER BELLS TABLE DECORATION',
#  461769: 'PACK OF 20 SKULL PAPER NAPKINS',
#  470022: 'LUNCH BAG SPACEBOY DESIGN ',
#  476637: 'GREEN REGENCY TEACUP AND SAUCER',
#  477267: 'ALARM CLOCK BAKELIKE RED ',
#  464709: 'PARTY CONES CANDY TREE DECORATION',
#  465255: 'STAR DECORATION RUSTIC',
#  466851: 'JIGSAW TREE WITH BIRDHOUSE',
#  485310: 'PARISIENNE KEY CABINET ',
#  475923: 'JUMBO BAG DOLLY GIRL DESIGN',
#  462630: '??',
#  460530: 'JUMBO STORAGE BAG SKULLS',
#  755391: 'ROSE FOLKART HEART DECORATIONS',
#  469560: 'GLASS JAR ENGLISH CONFECTIONERY',
#  435834: 'Found',
#  340599: 'HOUSE SHAPE PENCIL SHARPENER',
#  1788864: 'SET 4 VALENTINE DECOUPAGE HEART BOX',
#  450030: 'SET/3 RED GINGHAM ROSE STORAGE BOX',
#  473613: 'PLASTERS IN TIN SKULLS',
#  486171: 'ZINC SWEETHEART SOAP DISH',
#  484680: 'RED METAL BOX TOP SECRET',
#  460908: 'SET OF 6 CAKE CHOPSTICKS',
#  474096: 'check',
#  478611: 'T-LIGHT GLASS FLUTED ANTIQUE',
#  482580: 'PANTRY SCRUBBING BRUSH',
#  464289: 'FULL ENGLISH BREAKFAST PLATE',
#  479640: 'ROUND CAKE TIN VINTAGE RED',
#  468993: 'RETROSPOT PARTY BAG + STICKER SET',
#  468888: 'ROUND SNACK BOXES SET OF 4 FRUITS ',
#  440223: 'APPLE BATH SPONGE',
#  491673: 'DECROTIVEVINTAGE COFFEE GRINDER BOX',
#  494718: 'LANDMARK FRAME LONDON BRIDGE ',
#  458472: 'CHOCOLATE CALCULATOR',
#  468720: 'BIRDS MOBILE VINTAGE DESIGN',
#  489447: 'SET OF 60 PANTRY DESIGN CAKE CASES ',
#  490224: "JUMBO BAG 50'S CHRISTMAS ",
#  449001: 'MINI WOODEN HAPPY BIRTHDAY GARLAND',
#  477309: 'ALARM CLOCK BAKELIKE ORANGE',
#  444654: 'found',
#  476679: 'ROSES REGENCY TEACUP AND SAUCER ',
#  477792: 'SET 7 BABUSHKA NESTING BOXES',
#  462567: 'TEA PARTY BIRTHDAY CARD',
#  467985: 'DECORATION HEN ON NEST, HANGING',
#  482895: 'TRAVEL CARD WALLET SUKI',
#  1774689: 'SET OF 4 POLKADOT PLACEMATS ',
#  435078: 'RED RETROSPOT SHOPPER BAG',
#  466368: 'WOOD STAMP SET THANK YOU',
#  1662360: 'HEART SHAPE WIRELESS DOORBELL',
#  469035: 'HEART DECORATION PAINTED ZINC ',
#  486675: 'REGENCY MILK JUG PINK ',
#  1894200: 'GREEN SWEETHEART BRACELET',
#  475881: 'CHARLOTTE BAG DOLLY GIRL DESIGN',
#  448917: 'SMALL CAMPHOR WOOD FIELD  MUSHROOM',
#  1764126: 'MAGIC TREE -PAPER FLOWERS',
#  1785567: 'FRENCH CHATEAU LARGE PLATTER ',
#  465822: 'CAKE STAND VICTORIAN FILIGREE SMALL',
#  474327: 'check',
#  435099: 'WOODLAND CHARLOTTE BAG',
#  1528842: 'Wet pallet-thrown away',
#  488376: 'KIDS CUTLERY SPACEBOY ',
#  479094: 'CARD PARTY GAMES ',
#  1768788: 'HEN HOUSE WITH CHICK STANDING',
#  459354: 'GIN AND TONIC MUG',
#  997563: 'found',
#  477288: 'ALARM CLOCK BAKELIKE PINK',
#  491148: 'WOODLAND MINI RUCKSACK ',
#  456078: 'RED METAL BEACH SPADE ',
#  494907: 'EGG CUP HENRIETTA HEN PINK',
#  466116: 'SMALL HEART MEASURING SPOONS',
#  1788150: 'LADIES & GENTLEMEN METAL SIGN',
#  483210: 'CIRCUS PARADE BABY GIFT SET',
#  466179: 'FRYING PAN RED POLKADOT ',
#  452088: 'DAIRY MAID TRADITIONAL TEAPOT ',
#  477960: 'TRAY, BREAKFAST IN BED',
#  487998: 'SET OF 4 KNICK KNACK TINS LONDON ',
#  475230: 'DOLLY GIRL LUNCH BOX',
#  482139: 'check',
#  448518: 'TOAST ITS - HAPPY BIRTHDAY',
#  463911: 'EMPIRE TISSUE BOX',
#  1782312: 'TEATIME FUNKY FLOWER BACKPACK FOR 2',
#  1500639: 'HANGING JAM JAR T-LIGHT HOLDERS',
#  478191: 'CLEAR DRAWER KNOB ACRYLIC EDWARDIAN',
#  462609: 'SPACEBOY BIRTHDAY CARD',
#  212835: 'COLOURING PENCILS BROWN TUBE',
#  485016: 'PETIT TRAY CHIC',
#  477477: 'RIBBON REEL CHRISTMAS PRESENT ',
#  451983: 'DOORMAT FANCY FONT HOME SWEET HOME',
#  486465: 'LARGE CERAMIC TOP STORAGE JAR',
#  486066: 'TRIPLE HOOK ANTIQUE IVORY ROSE',
#  444318: 'MOODY GIRL DOOR HANGER ',
#  451647: 'ELEPHANT BIRTHDAY CARD ',
#  479304: '3 TIER SWEETHEART GARDEN SHELF',
#  451059: '?',
#  488061: 'TREASURE TIN GYMKHANA DESIGN',
#  494130: 'WALL ART,ONLY ONE PERSON ',
#  484092: 'RECYCLED ACAPULCO MAT TURQUOISE',
#  480165: 'HAND WARMER OWL DESIGN',
#  471786: 'FAIRY TALE COTTAGE NIGHT LIGHT',
#  481425: 'AMAZON',
#  1769859: 'check',
#  468615: '200 RED + WHITE BENDY STRAWS',
#  461475: 'PACK OF 60 DINOSAUR CAKE CASES',
#  481971: '60 CAKE CASES DOLLY GIRL DESIGN',
#  469602: 'GLASS JAR PEACOCK BATH SALTS',
#  490560: 'SET 8 CANDLES VINTAGE DOILEY',
#  442428: 'VINTAGE BILLBOARD LOVE/HATE MUG',
#  489489: 'SET OF 60 I LOVE LONDON CAKE CASES ',
#  466032: 'BLUE DINER WALL CLOCK',
#  445074: 'PINK  HONEYCOMB PAPER FAN',
#  1011864: 'DOORMAT ENGLISH ROSE ',
#  446670: 'ANTIQUE CREAM CUTLERY CUPBOARD',
#  485562: 'PARTY CHARMS 50 PIECES',
#  476805: 'WRAP GREEN PEARS ',
#  477120: 'SET OF 3 CAKE TINS PANTRY DESIGN ',
#  443226: 'CREAM SLICE FLANNEL CHOCOLATE SPOT ',
#  478800: 'ANTIQUE TALL SWIRLGLASS TRINKET POT',
#  489468: 'SET OF 60 VINTAGE LEAF CAKE CASES ',
#  1786029: 'Amazon',
#  476133: 'FRENCH GARDEN SIGN BLUE METAL',
#  482643: 'CARD BILLBOARD FONT',
#  447909: 'DINOSAURS  WRITING SET ',
#  474579: 'CHRISTMAS MUSICAL ZINC STAR',
#  1519329: 'SET/6 PURPLE BUTTERFLY T-LIGHTS',
#  440832: 'JAZZ HEARTS PURSE NOTEBOOK',
#  451185: 'RETROSPOT HEART HOT WATER BOTTLE',
#  482160: 'JAM MAKING SET WITH JARS',
#  463806: "PAPER CHAIN KIT 50'S CHRISTMAS ",
#  460005: 'MORE BUTTER METAL SIGN ',
#  786408: 'CERAMIC CAKE DESIGN SPOTTED MUG',
#  470610: 'MONEY BOX HOUSEKEEPING DESIGN',
#  487389: 'mailout',
#  455658: 'MOCK LOBSTER FRIDGE MAGNET',
#  446124: 'BLUE POLKADOT PLATE ',
#  465633: 'METAL 4 HOOK HANGER FRENCH CHATEAU',
#  472668: 'DOORSTOP RETROSPOT HEART',
#  339276: 'WRAP, CAROUSEL',
#  489258: 'BUNTING , SPOTTY ',
#  452739: 'STRAWBERRY LUNCH BOX WITH CUTLERY',
#  468405: 'COFFEE MUG PINK PAISLEY DESIGN',
#  443877: 'BLACK RECORD COVER FRAME',
#  1771392: 'Damages/samples',
#  340956: 'KITTY PENCIL ERASERS',
#  444675: 'GIN AND TONIC DIET METAL SIGN',
#  480984: 'CALENDAR PAPER CUT DESIGN',
#  463638: 'RIBBON REEL LACE DESIGN ',
#  487032: 'BUNDLE OF 3 ALPHABET EXERCISE BOOKS',
#  993510: 'SMALL POP BOX FUNKY MONKEY',
#  464079: 'CARAVAN SQUARE TISSUE BOX',
#  453411: 'check',
#  445557: 'RED RETROSPOT ROUND CAKE TINS',
#  476259: 'FRENCH BLUE METAL DOOR SIGN 4',
#  461307: 'PACK OF 12 SKULL TISSUES',
#  1773639: 'YELLOW METAL CHICKEN HEART ',
#  469686: 'DOORMAT AIRMAIL ',
#  457611: 'VINTAGE HEADS AND TAILS CARD GAME ',
#  492114: "3 RAFFIA RIBBONS 50'S CHRISTMAS ",
#  476658: 'PINK REGENCY TEACUP AND SAUCER',
#  473781: 'WOODEN SCHOOL COLOURING SET',
#  1660071: 'sold as set on dotcom',
#  491232: 'SPACEBOY ROCKET LOLLY MAKERS',
#  445998: 'RED RETROSPOT CUP',
#  467187: 'BUNNY DECORATION MAGIC GARDEN',
#  478737: 'damages',
#  480039: 'EASTER TIN BUNNY BOUQUET',
#  473928: '?? missing',
#  1784811: '60 TEATIME FAIRY CAKE CASES',
#  482706: 'GINGHAM ROSE WRAP',
#  434931: 'lost in space',
#  1734600: 'historic computer difference?....se',
#  479661: 'ROUND CAKE TIN VINTAGE GREEN',
#  478275: 'PURPLE DRAWERKNOB ACRYLIC EDWARDIAN',
#  1734243: '?',
#  1428: 'ebay',
#  210042: 'INFLATABLE POLITICAL GLOBE ',
#  450618: '2 PICTURE BOOK EGGS EASTER BUNNY',
#  454293: 'SUNFLOWER DECORATIVE PARASOL',
#  1783824: 'found',
#  1775256: 'FAIRY CAKES NOTEBOOK A7 SIZE',
#  1764651: 'CHARLIE+LOLA RED HOT WATER BOTTLE ',
#  1782396: 'damaged',
#  463617: '6 RIBBONS RUSTIC CHARM',
#  787059: 'sold as set by dotcom',
#  474348: 'CARD HOLDER GINGHAM HEART',
#  464961: 'CHRISTMAS CRAFT TREE TOP ANGEL',
#  486507: 'SMALL CERAMIC TOP STORAGE JAR ',
#  491316: 'BUTTERFLY CUSHION COVER',
#  786450: 'CERAMIC CAKE BOWL + HANGING CAKES',
#  1786239: 'FRENCH ENAMEL WATER BASIN',
#  441714: 'REX CASH+CARRY JUMBO SHOPPER',
#  1786491: 'RED CHARLIE+LOLA PERSONAL DOORSIGN',
#  463890: 'PAPER BUNTING RETROSPOT',
#  480942: 'TOTE BAG I LOVE LONDON',
#  474054: 'HEART WOODEN CHRISTMAS DECORATION',
#  463596: '6 RIBBONS EMPIRE  ',
#  486948: 'VINTAGE  2 METER FOLDING RULER',
#  490371: "ROLL WRAP 50'S CHRISTMAS",
#  467208: 'DECORATION  PINK CHICK MAGIC GARDEN',
#  485583: 'COCKTAIL SWORDS 50 PIECES',
#  487368: 'LUNCH BAG VINTAGE LEAF DESIGN',
#  487746: 'FILIGREE HEART DAISY WHITE',
#  491379: 'HOME SWEET HOME HANGING HEART',
#  460551: 'JUMBO STORAGE BAG SUKI',
#  477372: '3D VINTAGE CHRISTMAS STICKERS ',
#  494214: 'STOP FOR TEA WALL ART',
#  487263: 'mailout',
#  449295: 'BLUE POLKADOT BEAKER ',
#  468636: '200 BENDY SKULL STRAWS',
#  1789242: 'HANGING WOOD AND FELT HEART',
#  450219: 'BASKET OF TOADSTOOLS',
#  469098: 'STAR DECORATION PAINTED ZINC ',
#  481089: 'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#  358764: 'TRANQUILITY MASALA INCENSE',
#  493437: 'CLASSIC CROME BICYCLE BELL ',
#  786387: 'CERAMIC CAKE DESIGN SPOTTED PLATE',
#  481404: 'sold as set on dotcom',
#  461853: 'FLORAL FOLK STATIONERY SET',
#  455028: 'RED STRIPE CERAMIC DRAWER KNOB',
#  474810: 'PENS ASSORTED FUNNY FACE',
#  475902: 'LUNCH BAG DOLLY GIRL DESIGN',
#  1784937: '?',
#  1734138: 'KITCHEN METAL SIGN',
#  473571: 'PLASTERS IN TIN SPACEBOY',
#  1732206: '3 DRAWER ANTIQUE WHITE WOOD CABINET',
#  464310: 'BIRD HOUSE HOT WATER BOTTLE',
#  1765617: 'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
#  475083: 'BOX OF VINTAGE JIGSAW BLOCKS ',
#  490434: "6 GIFT TAGS 50'S CHRISTMAS ",
#  1784538: 'HANGING HEART JAR T-LIGHT HOLDER',
#  472542: 'reverse 21/5/10 adjustment',
#  444801: 'dotcom',
#  475986: 'RECIPE BOX PANTRY YELLOW DESIGN',
#  489678: 'BOX OF 6 MINI VINTAGE CRACKERS',
#  488040: 'SET OF 4 KNICK KNACK TINS  DOILEY ',
#  457653: 'check',
#  485772: 'SMALL IVORY HEART WALL ORGANISER',
#  450387: '12 IVORY ROSE PEG PLACE SETTINGS',
#  489972: 'IVORY WICKER HEART LARGE',
#  441294: 'check',
#  444549: "YOU'RE CONFUSING ME METAL SIGN ",
#  444612: 'PARTY METAL SIGN ',
#  477603: 'MAKE YOUR OWN FLOWERPOWER CARD KIT',
#  443583: 'SET/10 IVORY POLKADOT PARTY CANDLES',
#  486297: 'check',
#  473676: 'PLASTERS IN TIN CIRCUS PARADE ',
#  485331: 'PARISIENNE SEWING BOX',
#  493626: 'MINI PLAYING CARDS SPACEBOY ',
#  466599: '???lost',
#  459711: 'TRADITIONAL WOODEN SKIPPING ROPE',
#  487494: 'BELL HEART ANTIQUE GOLD',
#  476238: 'FRENCH BLUE METAL DOOR SIGN 3',
#  440181: 'STRAWBERRY BATH SPONGE ',
#  460236: 'SET 12 RETRO WHITE CHALK STICKS',
#  464373: 'GREY HEART HOT WATER BOTTLE',
#  443415: 'ROSE CARAVAN DOORSTOP',
#  472857: 'CHILDS GARDEN RAKE PINK',
#  463365: 'CHRISTMAS PUDDING TRINKET POT ',
#  482097: 'SET 3 PAPER VINTAGE CHICK PAPER EGG',
#  459480: 'RED RETROSPOT TAPE',
#  486108: 'MINITURE ANTIQUE ROSE HOOK IVORY',
#  465990: 'LOCAL CAFE MUG',
#  360465: "ASS COL LARGE SAND FROG P'WEIGHT",
#  471072: 'WATERING CAN PINK BUNNY',
#  464499: 'PEACE WOODEN BLOCK LETTERS',
#  490203: '20713',
#  470925: 'ENAMEL COLANDER CREAM',
#  470085: 'JUMBO BAG SPACEBOY DESIGN',
#  489741: 'SMALL WHITE HEART OF WICKER',
#  476532: 'DOORMAT WELCOME TO OUR HOME',
#  451479: 'BLUE POLKADOT WRAP',
#  471849: 'HEART OF WICKER SMALL',
#  467124: '3 HOOK HANGER MAGIC GARDEN',
#  464331: 'SCOTTIE DOG HOT WATER BOTTLE',
#  474285: 'PACK OF 6 BIRDY GIFT TAGS',
#  1788192: 'HAND OVER THE CHOCOLATE   SIGN ',
#  463470: 'SMALL RED RETROSPOT MUG IN BOX ',
#  489930: 'DECORATIVE WICKER HEART MEDIUM',
#  454608: 'ASSORTED TUTTI FRUTTI SMALL PURSE',
#  1892436: 'FRUIT SALAD BAG CHARM',
#  488544: 'SET OF 3 WOODEN SLEIGH DECORATIONS',
#  472605: 'MEMO BOARD COTTAGE DESIGN',
#  336945: 'check',
#  1781556: 'ZINC METAL HEART DECORATION',
#  480207: 'HAND WARMER BIRD DESIGN',
#  470043: 'LUNCH BAG SUKI  DESIGN ',
#  460068: 'CHOCOLATE THIS WAY METAL SIGN',
#  470316: 'MAGNETS PACK OF 4 RETRO PHOTO',
#  995820: 'ASSORTED COLOUR SUCTION CUP HOOK',
#  478695: 'SWEETHEART RECIPE BOOK STAND',
#  473214: 'MAGIC DRAWING SLATE SPACEBOY ',
#  487179: 'JUMBO BAG APPLES',
#  475251: 'CIRCUS PARADE LUNCH BOX ',
#  1779855: 'COLOUR GLASS T-LIGHT HOLDER HANGING',
#  476490: 'DOORMAT HOME SWEET HOME BLUE ',
#  490938: "PACK OF 12 50'S CHRISTMAS TISSUES",
#  454524: 'found',
#  736995: 'BLUE VICTORIAN FABRIC OVAL BOX',
#  1788696: 'SEWING SUSAN 21 NEEDLE SET',
#  473802: 'MONSTERS STENCIL CRAFT',
#  464394: 'HOT WATER BOTTLE TEA AND SYMPATHY',
#  487893: 'WRAP POPPIES  DESIGN',
#  478905: 'BLUE DRAWER KNOB ACRYLIC EDWARDIAN',
#  481278: 'HERB MARKER PARSLEY',
#  456561: 'COSY SLIPPER SHOES LARGE GREEN',
#  467376: 'FELT FARM ANIMAL CHICKEN',
#  477414: 'amazon sales',
#  472353: 'PAINT YOUR OWN CANVAS SET',
#  1722021: 'SILVER RECORD COVER FRAME',
#  468342: 'COFFEE MUG PEARS  DESIGN',
#  484071: 'RECYCLED ACAPULCO MAT BLUE',
#  463428: 'BLACK PIRATE TREASURE CHEST',
#  445326: 'STRAWBERRY HONEYCOMB  GARLAND ',
#  472731: 'RETROSPOT BABUSHKA DOORSTOP',
#  455091: 'RED SPOT CERAMIC DRAWER KNOB',
#  470106: 'JUMBO BAG PINK POLKADOT',
#  489783: 'WHITE WICKER STAR ',
#  490350: 'ROLL WRAP VINTAGE SPOT ',
#  480690: 'NOVELTY BISCUITS CAKE STAND 3 TIER',
#  472395: 'SET OF 2 ROUND TINS CAMEMBERT ',
#  473277: 'MAGIC DRAWING SLATE DINOSAUR',
#  488103: 'SET OF TEA COFFEE SUGAR TINS PANTRY',
#  1734180: 'BATHROOM METAL SIGN',
#  478758: 'ANTIQUE GLASS DRESSING TABLE POT',
#  483000: 'TRAVEL CARD WALLET TRANSPORT',
#  444444: 'HOME SWEET HOME METAL SIGN ',
#  446481: 'GREEN GOOSE FEATHER CHRISTMAS TREE ',
#  486633: 'REGENCY TEAPOT ROSES ',
#  456876: 'BATH BUILDING BLOCK WORD',
#  444381: 'KEEP OUT BOYS DOOR HANGER ',
#  440391: 'PINK BLUE FELT CRAFT TRINKET BOX',
#  477645: "POPPY'S PLAYHOUSE BEDROOM ",
#  489300: 'GARDENERS KNEELING PAD CUP OF TEA ',
#  1787394: 'RED ENCHANTED FOREST PLACEMAT',
#  437430: 'SILVER PHOTO FRAME',
#  448938: 'SMALL TALL CAMPHOR WOOD TOADSTOOL',
#  1011948: 'DOORMAT WELCOME PUPPIES',
#  476784: 'WRAP RED APPLES ',
#  488607: 'SET OF 4 SANTA PLACE SETTINGS',
#  481698: 'CUPCAKE LACE PAPER SET 6',
#  468363: 'COFFEE MUG APPLES DESIGN',
#  463344: 'PINK DOUGHNUT TRINKET POT ',
#  466410: 'WOOD STAMP SET BEST WISHES',
#  840021: 'check',
#  1665741: 'CHILLI LIGHTS',
#  460467: 'BLUE/CREAM STRIPE CUSHION COVER ',
#  1788423: 'WHITE BAROQUE WALL CLOCK ',
#  477897: 'LARGE RED BABUSHKA NOTEBOOK ',
#  787500: 'TEA TIME TEAPOT IN GIFT BOX',
#  493878: 'EMBROIDERED RIBBON REEL RACHEL ',
#  451626: 'FANCY FONT BIRTHDAY CARD, ',
#  482979: 'TRAVEL CARD WALLET RETRO PETALS',
#  315819: 'SANDALWOOD FAN',
#  1890294: 'SILVER AND BLACK ORBIT NECKLACE',
#  475566: 'CERAMIC STRAWBERRY CAKE MONEY BANK',
#  491442: 'HOME SWEEET HOME 3 PEG HANGER ',
#  474117: 'check',
#  452676: 'CERAMIC STRAWBERRY MONEY BOX',
#  483252: 'GLASS APOTHECARY BOTTLE PERFUME',
#  1780716: 'BLUE SAVANNAH PICNIC HAMPER FOR 2',
#  443541: 'SET/10 RED POLKADOT PARTY CANDLES',
#  448980: 'WOODEN HAPPY BIRTHDAY GARLAND',
#  471807: 'wrongly sold (22719) barcode',
#  476091: 'FRENCH LAUNDRY SIGN BLUE METAL',
#  460194: 'BLUE HARMONICA IN BOX ',
#  480963: 'CALENDAR FAMILY FAVOURITES',
#  464457: 'check',
#  487872: 'WRAP VINTAGE PETALS  DESIGN',
#  450555: 'PAINTED YELLOW WOODEN DAISY',
#  471954: 'SPACEBOY TV DINNER TRAY',
#  452718: 'SKULL LUNCH BOX WITH CUTLERY ',
#  475545: 'CERAMIC HEART FAIRY CAKE MONEY BANK',
#  1776201: 'check',
#  460593: 'PINK VINTAGE PAISLEY PICNIC BAG',
#  446082: 'RED RETROSPOT PLATE ',
#  464604: 'SET OF 2 TEA TOWELS PING MICROWAVE',
#  446040: 'BLUE POLKADOT CUP',
#  1764609: 'RED WOOLLY HOTTIE WHITE HEART.',
#  471597: 'NATURAL SLATE HEART CHALKBOARD ',
#  471261: 'GROW YOUR OWN BASIL IN ENAMEL MUG',
#  472248: 'NATURAL SLATE RECTANGLE CHALKBOARD',
#  462987: 'EMPIRE GIFT WRAP',
#  490266: 'SPACEBOY BEAKER',
#  485520: 'PACK OF 6 SMALL FRUIT STRAWS',
#  469896: 'AIRLINE BAG VINTAGE JET SET WHITE',
#  478296: 'CAKESTAND, 3 TIER, LOVEHEART',
#  471660: 'EMBOSSED GLASS TEALIGHT HOLDER',
#  471219: '6 ROCKET BALLOONS ',
#  467796: 'WASH BAG VINTAGE ROSE PAISLEY',
#  486339: 'SET OF 5 PANCAKE DAY MAGNETS',
#  469917: 'BOTTLE BAG RETROSPOT ',
#  486591: 'REGENCY TEA PLATE GREEN ',
#  455259: 'SKULLS  STICKERS',
#  1776789: 'damages',
#  479535: 'HOT WATER BOTTLE I AM SO POORLY',
#  487620: 'REINDEER HEART DECORATION GOLD',
#  487662: 'CHRISTMAS TREE HANGING GOLD',
#  435246: 'LUNCH BAG WOODLAND',
#  434259: 'EDWARDIAN PARASOL RED',
#  481488: 'YELLOW GIANT GARDEN THERMOMETER',
#  489048: 'check',
#  440601: '12 PENCILS TALL TUBE WOODLAND',
#  460635: 'SUKI  SHOULDER BAG',
#  489027: 'RED VINTAGE SPOT BEAKER',
#  478716: 'Not rcvd in 10/11/2010 delivery',
#  440454: '12 PENCILS SMALL TUBE SKULL',
#  755013: 'FOLKART STAR CHRISTMAS DECORATIONS',
#  467061: 'GARLAND WOODEN HAPPY EASTER',
#  475692: 'check',
#  755181: 'FOLKART ZINC HEART CHRISTMAS DEC',
#  482265: '3 TRADITIONAL COOKIE CUTTERS  SET',
#  340935: 'RECYCLED PENCIL WITH RABBIT ERASER',
#  478884: 'Wrongly mrked had 85123a in box',
#  451164: 'CHICK GREY HOT WATER BOTTLE',
#  477330: 'ALARM CLOCK BAKELIKE IVORY',
#  340977: 'SLEEPING CAT ERASERS',
#  1782459: 'damaged',
#  1776180: 'MOUSE TOY WITH PINK T-SHIRT',
#  492996: 'WOODLAND LARGE RED FELT HEART',
#  441315: 'DARK BIRD HOUSE TREE DECORATION',
#  476889: 'WRAP WEDDING DAY',
#  494781: 'SET OF 6 RIBBONS PARTY',
#  452781: 'DINOSAUR LUNCH BOX WITH CUTLERY',
#  454125: 'VINTAGE UNION JACK APRON',
#  315924: 'BLUE PAPER PARASOL ',
#  470820: 'LIPSTICK PEN BABY PINK',
#  473550: 'HOLIDAY FUN LUDO',
#  494067: 'ANIMALS AND NATURE WALL ART',
#  482181: 'JAM MAKING SET PRINTED',
#  1787709: 'BEADED CRYSTAL HEART BLUE SMALL',
#  470757: 'PACK OF 60 SPACEBOY CAKE CASES',
#  484344: 'Crushed',
#  456729: 'LARGE RED RETROSPOT WINDMILL',
#  461706: 'PACK OF 12 PINK POLKADOT TISSUES',
#  446712: '?',
#  1782480: 'WHITE WIRE EGG HOLDER',
#  466011: 'IVORY DINER WALL CLOCK',
#  491757: 'BATHROOM HOOK',
#  470358: 'MAGNETS PACK OF 4 SWALLOWS',
#  471345: 'PENCIL CASE LIFE IS BEAUTIFUL',
#  462672: 'BOTANICAL LILY GREETING CARD',
#  489174: 'SET OF 6 SNACK LOAF BAKING CASES',
#  1788738: 'VICTORIAN SEWING KIT',
#  1785294: 'BLACK/BLUE POLKADOT UMBRELLA',
#  463239: 'CERAMIC STRAWBERRY DESIGN MUG',
#  440643: '12 PENCILS TALL TUBE RED RETROSPOT',
#  474537: 'CHRISTMAS MUSICAL ZINC HEART ',
#  481845: 'sold as set on dotcom',
#  1775571: 'CROCHET DOG KEYRING',
#  487767: 'FILIGREE HEART BUTTERFLY WHITE ',
#  449085: 'IVORY HANGING DECORATION  HEART',
#  1720992: 'ROUND BLUE CLOCK WITH SUCKER',
#  465087: 'check',
#  484638: 'ICE CREAM PEN LIP GLOSS ',
#  490707: 'SET 12 COLOUR PENCILS SPACEBOY ',
#  443310: 'LARGE CAKE TOWEL PINK SPOTS',
#  477939: 'found',
#  469980: 'TOY TIDY SPACEBOY  ',
#  468741: 'BIRD DECORATION RED RETROSPOT',
#  444927: 'WHITE BELL HONEYCOMB PAPER GARLAND ',
#  1011927: 'DOORMAT NEW ENGLAND',
#  455763: 'BAG 125g SWIRLY MARBLES',
#  440433: '12 PENCIL SMALL TUBE WOODLAND',
#  487242: 'mailout',
#  472710: 'GINGHAM BABUSHKA DOORSTOP',
#  459900: 'KEY FOB , SHED',
#  480837: 'OVEN MITT APPLES DESIGN',
#  1894494: 'LETTER "U" BLING KEY RING',
#  468846: 'ROUND SNACK BOXES SET OF4 WOODLAND ',
#  474516: 'CHRISTMAS STAR WISH LIST CHALKBOARD',
#  1785420: 'ROUND PINK HEART MIRROR',
#  487473: 'STAR WREATH DECORATION WITH BELL',
#  468489: 'TEA COSY RED  STRIPE',
#  493647: 'MINI PLAYING CARDS BUFFALO BILL ',
#  485352: 'PARISIENNE CURIO CABINET',
#  494235: 'BICYCLE SAFTEY WALL ART',
#  474453: 'CHRISTMAS GINGHAM STAR',
#  470778: '10 COLOUR SPACEBOY PEN',
#  483126: 'TRAVEL CARD WALLET FLOWER MEADOW',
#  481782: 'CHRISTMAS LIGHTS 10 SANTAS ',
#  490665: 'SET 12 COLOUR PENCILS LOVE LONDON',
#  1788843: 'CHARLIE & LOLA WASTEPAPER BIN FLORA',
#  486234: 'SET OF 4 JAM JAR MAGNETS',
#  472185: 'SET OF 2 WOODEN MARKET CRATES',
#  480333: 'NUMBER TILE COTTAGE GARDEN 5',
#  465150: '3 STRIPEY MICE FELTCRAFT',
#  476574: 'WICKER STAR ',
#  476553: 'GROW A FLYTRAP OR SUNFLOWER IN TIN',
#  445620: 'SET/4 BADGES DOGS',
#  469665: 'DOORMAT RESPECTABLE HOUSE',
#  471051: 'WATERING CAN BLUE ELEPHANT',
#  476175: 'FRENCH KITCHEN SIGN BLUE METAL',
#  486822: 'TOILET SIGN OCCUPIED OR VACANT',
#  460026: 'PHARMACIE FIRST AID TIN',
#  456834: 'HOME BUILDING BLOCK WORD',
#  494025: 'BUFFALO BILL WALL ART ',
#  459438: 'PACK OF 6 SANDCASTLE FLAGS ASSORTED',
#  473865: 'FELTCRAFT HAIRBANDS PINK AND WHITE ',
#  478086: 'PHOTO FRAME CORNICE',
#  340998: 'PARTY TIME PENCIL ERASERS',
#  495201: 'JUMBO BAG PAISLEY PARK',
#  481992: '72 CAKE CASES VINTAGE CHRISTMAS',
#  462651: 'BOTANICAL LAVENDER BIRTHDAY CARD',
#  467943: '6 EGG HOUSE PAINTED WOOD',
#  1894368: 'PAIR OF PINK FLOWER CLUSTER SLIDE',
#  477771: 'FELTCRAFT PRINCESS OLIVIA DOLL',
#  471996: 'EMPIRE UNION JACK TV DINNER TRAY',
#  434154: 'GREEN POLKADOT BOWL',
#  466053: 'RED DINER WALL CLOCK',
#  465759: 'SET 10 LIGHTS NIGHT OWL',
#  754215: 'damaged',
#  449463: 'BLUE EGG  SPOON',
#  480900: ' SET 2 TEA TOWELS I LOVE LONDON ',
#  484176: 'CRYSTAL CHANDELIER T-LIGHT HOLDER',
#  1783929: 'SILVER HANGING T-LIGHT HOLDER',
#  463323: 'CERAMIC BOWL WITH STRAWBERRY DESIGN',
#  1732164: 'WOOD BLACK BOARD ANT WHITE FINISH',
#  473718: 'CLOTHES PEGS RETROSPOT PACK 24 ',
#  479115: 'CARD PSYCHEDELIC APPLES',
#  449190: 'FILIGRIS HEART WITH BUTTERFLY',
#  472521: 'incorrectly put back into stock',
#  481131: 'PAPER CHAIN KIT LONDON',
#  480123: 'SOAP DISH BROCANTE',
#  433818: 'RED RETROSPOT LUGGAGE TAG',
#  482622: 'PANTRY PASTRY BRUSH',
#  489846: 'HANGING MINI COLOURED BOTTLES',
#  1783866: 'ANTIQUE SILVER TEA GLASS ETCHED',
#  460509: 'JUMBO BAG PINK VINTAGE PAISLEY',
#  1780632: 'ENCHANTED BIRD COATHANGER 5 HOOK',
#  486423: 'REGENCY SUGAR TONGS',
#  481551: 'BAKING MOULD HEART WHITE CHOCOLATE',
#  1011885: '?',
#  483273: 'GLASS APOTHECARY BOTTLE TONIC',
#  1789767: 'SET OF 6 3D KIT CARDS FOR KIDS',
#  477351: '3D CHRISTMAS STAMPS STICKERS ',
#  463680: 'RIBBON REEL POLKADOTS ',
#  440349: 'RED FLORAL FELTCRAFT SHOULDER BAG',
#  442638: 'SET/20 STRAWBERRY PAPER NAPKINS ',
#  469308: 'TEA BAG PLATE RED RETROSPOT',
#  484554: 'EMBOSSED HEART TRINKET BOX',
#  474033: 'STAR WOODEN CHRISTMAS DECORATION',
#  469518: 'KINGS CHOICE TEA CADDY ',
#  460152: 'VINTAGE SNAKES & LADDERS',
#  468867: 'ROUND SNACK BOXES SET OF 4 SKULLS',
#  486801: 'BULL DOG BOTTLE TOP WALL CLOCK',
#  480438: 'NUMBER TILE COTTAGE GARDEN No',
#  442281: 'PARTY INVITES FOOTBALL',
#  461790: 'MODERN FLORAL STATIONERY SET',
#  1785756: 'damages wax',
#  1775235: 'FAIRY CAKES NOTEBOOK A6 SIZE',
#  491904: 'GINGHAM RECIPE BOOK BOX',
#  444255: 'RED RETROSPOT PEG BAG',
#  483693: 'DRAWER KNOB CERAMIC RED',
#  492177: "GIFT BAG LARGE 50'S CHRISTMAS",
#  480858: 'CHILDRENS APRON APPLES DESIGN',
#  481467: 'damaged',
#  494466: 'WRAP PAISLEY PARK ',
#  465801: 'check',
#  1783950: 'ASSORTED COLOUR T-LIGHT HOLDER',
#  477687: "POPPY'S PLAYHOUSE BATHROOM",
#  477708: "POPPY'S PLAYHOUSE KITCHEN",
#  471828: 'BABUSHKA LIGHTS STRING OF 10',
#  445578: 'RED SPOTTY BISCUIT TIN',
#  460614: 'SKULL SHOULDER BAG',
#  1787772: 'damages',
#  467733: 'FELTCRAFT DOLL MOLLY',
#  468531: 'OFFICE MUG WARMER BLACK+SILVER ',
#  462945: 'SPACEBOY GIFT WRAP',
#  440664: 'damaged',
#  482202: 'JAM JAR WITH PINK LID',
#  447027: 'SCENTED VELVET LOUNGE CANDLE ',
#  484008: 'SET OF 10 LANTERNS FAIRY LIGHT STAR',
#  477183: 'SET OF 6 HERB TINS SKETCHBOOK',
#  490182: 'MINT DINER CLOCK',
#  461517: 'PACK OF 60 PINK PAISLEY CAKE CASES',
#  454272: 'VINTAGE PINK DECORATIVE PARASOL',
#  484764: 'for online retail orders',
#  487284: 'CHARLOTTE BAG APPLES DESIGN',
#  465276: 'HEART DECORATION WITH PEARLS ',
#  450870: 'FLOWER VINE RAFFIA FOOD COVER',
#  449778: 'STARFISH SOAP DISH',
#  433713: 'CHERRY BLOSSOM LUGGAGE TAG',
#  478422: 'SET 3 WICKER STORAGE BASKETS ',
#  460866: 'PARTY TIME DESIGN FLANNEL',
#  454944: 'RIDGED GLASS STORAGE JAR CREAM LID',
#  1890777: 'TINY CRYSTAL BRACELET RED',
#  463512: 'RED RETROSPOT TEA CUP AND SAUCER ',
#  446019: 'PINK  POLKADOT CUP',
#  316218: 'wet/rusty',
#  998907: 'TEA TIME KITCHEN APRON',
#  488355: 'CHILDRENS CUTLERY CIRCUS PARADE',
#  1789284: 'lost??',
#  458493: 'damages',
#  456393: 'RED HANGING HEART T-LIGHT HOLDER',
#  490413: '6 GIFT TAGS VINTAGE CHRISTMAS ',
#  487557: 'LAUREL HEART ANTIQUE SILVER',
#  456855: 'LOVE BUILDING BLOCK WORD',
#  486570: 'REGENCY TEA PLATE ROSES ',
#  999474: 'SCOTTIES DESIGN WASHBAG',
#  453789: 'SET 12 LAVENDER  BOTANICAL T-LIGHTS',
#  440916: 'JAZZ HEARTS ADDRESS BOOK',
#  475041: 'TRADITIONAL KNITTING NANCY',
#  481383: 'sold as set on dotcom',
#  434385: 'DOORMAT RED RETROSPOT',
#  475167: 'MINT KITCHEN SCALES',
#  443058: 'damages?',
#  467481: 'FELT EGG COSY WHITE RABBIT ',
#  470673: 'METAL SIGN TAKE IT OR LEAVE IT ',
#  435183: 'STRAWBERRY CHARLOTTE BAG',
#  456666: 'SMALL RED RETROSPOT WINDMILL',
#  485478: 'check',
#  464583: 'PING MICROWAVE APRON',
#  481761: 'CHRISTMAS LIGHTS 10 REINDEER',
#  1774710: 'SET OF 4 POLKADOT COASTERS',
#  435750: 'RED RETROSPOT MINI CASES',
#  473760: 'TRADITIONAL MODELLING CLAY',
#  470967: 'damages',
#  483105: 'printing smudges/thrown away',
#  475377: 'damages',
#  999180: 'TEA TIME DES TEA COSY',
#  469119: 'check',
#  479472: 'BROCANTE SHELF WITH HOOKS',
#  477498: 'RIBBON REEL SNOWY VILLAGE',
#  470988: 'ENAMEL FIRE BUCKET CREAM',
#  440559: '36 PENCILS TUBE RED RETROSPOT',
#  465927: 'GREEN CHRISTMAS TREE CARD HOLDER',
#  483168: 'DOLLY GIRL BABY GIFT SET',
#  467838: 'OVERNIGHT BAG VINTAGE ROSE PAISLEY',
#  474495: 'check',
#  1514751: 'COLUMBIAN CANDLE RECTANGLE',
#  1783446: 'LA PALMIERA TILE COASTER',
#  471303: 'GROW YOUR OWN HERBS SET OF 3',
#  480186: 'HAND WARMER SCOTTY DOG DESIGN',
#  441378: 'damaged',
#  486969: 'SET OF 12 FORK CANDLES',
#  455070: 'BLUE SPOT CERAMIC DRAWER KNOB',
#  485793: 'LARGE IVORY HEART WALL ORGANISER',
#  442890: 'WET/MOULDY',
#  490161: 'PINK DINER WALL CLOCK',
#  1891974: 'NECKLACE+BRACELET SET FRUIT SALAD ',
#  453138: '?',
#  1774899: 'TOMATO CHARLIE+LOLA COASTER SET',
#  449568: 'SPOTTY PINK DUCK DOORSTOP',
#  465528: 'ORGANISER WOOD ANTIQUE WHITE ',
#  452235: 'RED RETROSPOT SMALL MILK JUG',
#  474600: 'CHRISTMAS RETROSPOT STAR WOOD',
#  465171: 'PLACE SETTING WHITE HEART',
#  463764: 'PAPER CHAIN KIT EMPIRE',
#  460047: "I'M ON HOLIDAY METAL SIGN",
#  493668: 'MINI PLAYING CARDS DOLLY GIRL ',
#  455175: 'BUTTERFLIES STICKERS',
#  492219: 'HAND WARMER RED LOVE HEART',
#  490098: 'EGG FRYING PAN RED ',
#  755370: 'ZINC FOLKART SLEIGH BELLS',
#  441819: 'RED RETROSPOT SHOPPING BAG',
#  478107: 'TRIPLE PHOTO FRAME CORNICE ',
#  447111: 'SMALL POLKADOT CHOCOLATE GIFT BAG ',
#  473634: 'PLASTERS IN TIN WOODLAND ANIMALS',
#  1786638: 'missing',
#  452424: 'SKULLS  WATER TRANSFER TATTOOS ',
#  479766: 'BREAD BIN DINER STYLE RED ',
#  784140: 'sold as set on dotcom',
#  467691: 'check',
#  492051: 'NATURAL HANGING QUILTED HEARTS ',
#  482223: 'JAM JAR WITH BLUE LID',
#  473844: 'ALPHABET STENCIL CRAFT',
#  493311: 'VINTAGE JINGLE BELLS HEART',
#  475524: 'CERAMIC CHERRY CAKE MONEY BANK',
#  474957: 'mouldy, thrown away.',
#  1785840: 'S/4 PINK FLOWER CANDLES IN BOWL',
#  457506: 'check',
#  484659: ' TOADSTOOL BEDSIDE LIGHT ',
#  489867: 'HANGING CLEAR MINI BOTTLE',
#  476154: 'FRENCH TOILET SIGN BLUE METAL',
#  464982: 'check',
#  472101: 'wet boxes',
#  493374: 'VINTAGE DOILY DELUXE SEWING KIT ',
#  469707: 'CHILDRENS APRON SPACEBOY DESIGN',
#  475209: 'SPACEBOY LUNCH BOX ',
#  479724: 'VINTAGE CREAM DOG FOOD CONTAINER',
#  472920: 'CHILDS GARDEN TROWEL BLUE ',
#  474159: 'dotcom',
#  467145: 'HOOK, 1 HANGER ,MAGIC GARDEN',
#  440685: 'HEART CALCULATOR',
#  487347: 'LUNCH BAG ALPHABET DESIGN',
#  434952: 'JUMBO BAG WOODLAND ANIMALS',
#  484449: 'EDWARDIAN PHOTO FRAME',
#  477834: 'SMALL RED BABUSHKA NOTEBOOK ',
#  451584: 'SKULLS GREETING CARD',
#  1771980: 'SET OF 3 BUTTERFLY COOKIE CUTTERS',
#  462924: 'CHRISTMAS CARD STACK OF PRESENTS',
#  486717: 'TREASURE ISLAND BOOK BOX',
#  471744: 'HANGING METAL HEART LANTERN',
#  477435: 'RIBBON REEL SOCKS AND MITTENS',
#  464352: 'CHOCOLATE HOT WATER BOTTLE',
#  477666: "POPPY'S PLAYHOUSE LIVINGROOM ",
#  446439: 'VICTORIAN SEWING BOX SMALL ',
#  459165: 'PINK UNION JACK  PASSPORT COVER ',
#  1783887: 'ANTIQUE SILVER TEA GLASS ENGRAVED',
#  464226: 'MIRROR MOSAIC HURRICANE LAMP ',
#  487221: 'JUMBO BAG ALPHABET',
#  449862: 'PORCELAIN ROSE SMALL',
#  480816: 'PEG BAG APPLE DESIGN',
#  479010: 'check',
#  451668: 'VINTAGE KID DOLLY CARD ',
#  475419: 'SET OF 4 NAPKIN CHARMS HEARTS',
#  497301: 'LUNCH BAG RED VINTAGE DOILY',
#  476994: 'CARD BIRTHDAY COWBOY',
#  483945: 'PAPER LANTERN 5 POINT STAR MOON 30',
#  462777: 'ROBOT BIRTHDAY CARD',
#  459564: 'CAKES AND BOWS GIFT  TAPE',
#  481614: 'BAKING MOULD EASTER EGG WHITE CHOC',
#  1785672: 'damaged',
#  465192: 'check',
#  466767: 'HANGING HEART MIRROR DECORATION ',
#  457401: 'damages?',
#  486549: 'smashed',
#  784770: 'damages/dotcom?',
#  464415: 'METAL SIGN EMPIRE TEA',
#  469539: 'GLASS JAR KINGS CHOICE',
#  449043: 'PACK OF 12 STICKY BUNNIES',
#  447594: 'SMALL GLASS HEART TRINKET POT',
#  1894305: 'LARGE CRYSTAL DIAMANTE HAIRSLIDE',
#  477015: 'CARD WEDDING DAY',
#  1768578: 'BOX/12 CHICK & EGG IN BASKET',
#  475713: 'BUTTON BOX ',
#  457527: 'RAIN PONCHO RETROSPOT',
#  479052: '?',
#  472374: 'EMERGENCY FIRST AID TIN ',
#  481110: 'PAPER CHAIN KIT VINTAGE CHRISTMAS',
#  357252: 'ORIGAMI OPIUM INCENSE/CANDLE SET ',
#  1783509: 'code mix up? 84930',
#  476406: 'FRENCH BLUE METAL DOOR SIGN No',
#  432936: 'CHERRY BLOSSOM PASSPORT COVER',
#  478023: 'KEY CABINET MA CAMPAGNE',
#  494634: 'LANDMARK FRAME OXFORD STREET',
#  494382: "70'S ALPHABET WALL ART",
#  449988: 'SET3 BOOK BOX GREEN GINGHAM FLOWER ',
#  461685: 'PACK OF 12 HEARTS DESIGN TISSUES ',
#  1783299: 'BLUE CUSHION COVER WITH FLOWER',
#  466788: 'BUNNY WOODEN PAINTED WITH BIRD ',
#  459207: 'PINK UNION JACK  LUGGAGE TAG',
#  444087: 'found',
#  456435: 'damages',
#  452214: 'DAIRY MAID LARGE MILK JUG',
#  752178: 'adjustment',
#  474705: 'WOODEN CROQUET GARDEN SET',
#  433692: 'check',
#  1527561: 'GRAND CHOCOLATECANDLE',
#  476910: 'WRAP I LOVE LONDON ',
#  479745: 'VINTAGE CREAM CAT FOOD CONTAINER',
#  470799: 'LIPSTICK PEN RED',
#  493689: 'MINI PLAYING CARDS FUN FAIR ',
#  1071294: 'FEATHER PEN,LIGHT PINK',
#  455049: 'BLUE STRIPE CERAMIC DRAWER KNOB',
#  448959: 'CAMPHOR WOOD PORTOBELLO MUSHROOM',
#  469455: 'test',
#  494046: 'DOG LICENCE WALL ART',
#  482244: '3 PIECE SPACEBOY COOKIE CUTTER SET',
#  475860: 'DOORMAT I LOVE LONDON',
#  482286: 'GINGERBREAD MAN COOKIE CUTTER',
#  441252: 'ANTIQUE ALL GLASS CANDLESTICK',
#  1891239: 'DIAMANTE HAIR GRIP PACK/2 BLACK DIA',
#  840336: 'damaged stock',
#  479514: 'HAND WARMER BABUSHKA DESIGN',
#  459270: 'I CAN ONLY PLEASE ONE PERSON MUG',
#  482853: 'SET OF 4 PANTRY JELLY MOULDS',
#  473991: 'ROCKING HORSE RED CHRISTMAS ',
#  454041: '?',
#  487956: 'STORAGE TIN VINTAGE DOILEY ',
#  472122: 'BLUE TEA TOWEL CLASSIC DESIGN',
#  469476: 'CHARLOTTE BAG PINK POLKADOT',
#  468762: 'BIRD DECORATION GREEN POLKADOT',
#  488733: 'HEART T-LIGHT HOLDER WILLIE WINKIE',
#  1778532: 'BOX OF 24 COCKTAIL PARASOLS',
#  434196: 'RED RETROSPOT BOWL',
#  1772526: 'incorrectly made-thrown away.',
#  435771: 'check',
#  492891: 'SIX DRAWER OFFICE TIDY',
#  468237: 'HEART IVORY TRELLIS SMALL',
#  437976: '??',
#  459774: 'POTTING SHED SEED ENVELOPES',
#  447846: 'AGED GLASS SILVER T-LIGHT HOLDER',
#  445095: 'PINK  HONEYCOMB PAPER BALL ',
#  456183: 'ALPHABET HEARTS STICKER SHEET',
#  440706: 'BLUE CALCULATOR RULER',
#  464520: 'WELCOME  WOODEN BLOCK LETTERS',
#  489279: 'FOOD COVER WITH BEADS , SET 2 SIZES',
#  483987: 'PAPER LANTERN 5 POINT SEQUIN STAR',
#  475146: 'BLACK KITCHEN SCALES',
#  448728: 'MIRRORED WALL ART LADIES',
#  474180: 'ADVENT CALENDAR GINGHAM SACK',
#  1776516: '??',
#  1785315: 'SET OF 12  VINTAGE POSTCARD SET',
#  379974: 'WHITE AND BLUE CERAMIC OIL BURNER',
#  447888: 'BALLOONS  WRITING SET ',
#  455448: 'mixed up',
#  472941: 'CHILDS GARDEN TROWEL PINK',
#  486780: "MUM'S KITCHEN CLOCK",
#  1576029: 'LARGE CIRCULAR MIRROR MOBILE',
#  486654: 'REGENCY SUGAR BOWL GREEN',
#  1769271: 'GREETING CARD, STICKY GORDON',
#  432915: 'BLUE POLKADOT PASSPORT COVER',
#  459291: 'SAVE THE PLANET MUG',
#  465591: '?',
#  464772: 'RED LOVE HEART SHAPE CUP',
#  476049: 'RED BABY BUNTING ',
#  ...}

# %%
sample_codes = [477792,1764609,456330,1772526,1492113,1787583]  # int
descriptions = {code: find_item_description(code) for code in sample_codes}


for code, desc in descriptions.items():
    print(f"ItemCode: {code} -> Description: {desc}")
# Out:
# ItemCode: 477792 -> Description: SET 7 BABUSHKA NESTING BOXES
# ItemCode: 1764609 -> Description: RED WOOLLY HOTTIE WHITE HEART.
# ItemCode: 456330 -> Description: GLASS STAR FROSTED T-LIGHT HOLDER
# ItemCode: 1772526 -> Description: incorrectly made-thrown away.
# ItemCode: 1492113 -> Description: WHITE MOROCCAN METAL LANTERN
# ItemCode: 1787583 -> Description: wrongly marked carton 22804

# %%
import pandas as pd

df_lookup = pd.read_csv('transaction_data.csv', engine='python')

# 建立 ItemCode 與 ItemDescription 的對照表
item_lookup = df_lookup[['ItemCode', 'ItemDescription']].drop_duplicates().set_index('ItemCode')['ItemDescription'].to_dict()

# 定義查詢函數
def find_item_description(item_code):
    return item_lookup.get(str(item_code), "Unknown")

item_lookup
# Out:
# {465549: 'FAMILY ALBUM WHITE PICTURE FRAME',
#  482370: 'LONDON BUS COFFEE MUG',
#  490728: 'SET 12 COLOUR PENCILS DOLLY GIRL ',
#  459186: 'UNION JACK FLAG LUGGAGE TAG',
#  1733592: 'WASHROOM METAL SIGN',
#  1787247: nan,
#  471576: 'NATURAL SLATE CHALKBOARD LARGE ',
#  447867: 'SKULLS WRITING SET ',
#  1783845: 'MULTI COLOUR SILVER T-LIGHT HOLDER',
#  494802: 'SET OF 6 RIBBONS PERFECTLY PRETTY  ',
#  460215: 'John Lewis',
#  459669: 'WOODEN BOX OF DOMINOES',
#  486276: 'SET OF 5 MINI GROCERY MAGNETS',
#  435225: 'LUNCH BAG RED SPOTTY',
#  455868: 'FOLDING UMBRELLA CREAM POLKADOT',
#  477246: nan,
#  477036: 'CARD CIRCUS PARADE',
#  489594: 'VINTAGE CHRISTMAS TABLECLOTH',
#  1771938: 'SET OF 3 HEART COOKIE CUTTERS',
#  461622: 'PACK OF 12 SUKI TISSUES ',
#  476028: 'PINK BABY BUNTING',
#  434028: 'DISCO BALL CHRISTMAS DECORATION',
#  474726: nan,
#  490329: 'ROLL WRAP VINTAGE CHRISTMAS',
#  443436: nan,
#  464751: 'FOOD CONTAINER SET 3 LOVE HEART ',
#  452844: 'PINK  HEART SHAPE LOVE BUCKET ',
#  485667: 'DOLLCRAFT GIRL NICOLE',
#  469392: 'LUNCH BOX WITH CUTLERY RETROSPOT ',
#  453348: 'RETROSPOT GIANT TUBE MATCHES',
#  482559: 'PANTRY WASHING UP BRUSH',
#  460656: 'RED RETROSPOT PICNIC BAG',
#  488019: 'SET OF 4 KNICK KNACK TINS POPPIES',
#  441735: 'SET/2 RED RETROSPOT TEA TOWELS ',
#  472647: 'MEMO BOARD RETROSPOT  DESIGN',
#  435204: 'RED RETROSPOT CHARLOTTE BAG',
#  436380: 'BLACK EAR MUFF HEADPHONES',
#  434973: 'found',
#  475839: 'LUNCH BOX I LOVE LONDON',
#  1784370: 'SINGLE HEART ZINC T-LIGHT HOLDER',
#  476007: 'damaged',
#  469875: 'AIRLINE BAG VINTAGE JET SET BROWN',
#  445452: 'PACK OF 72 RETROSPOT CAKE CASES',
#  440370: 'PINK FLORAL FELTCRAFT SHOULDER BAG',
#  1784832: '72 SWEETHEART FAIRY CAKE CASES',
#  456351: 'RED TOADSTOOL LED NIGHT LIGHT',
#  459963: 'MAN FLU METAL SIGN',
#  435288: 'LUNCH BAG CARS BLUE',
#  444759: nan,
#  454818: nan,
#  474873: 'PACK OF 20 SPACEBOY NAPKINS',
#  440538: '36 PENCILS TUBE SKULLS',
#  461664: 'PACK OF 12 PINK PAISLEY TISSUES ',
#  465738: 'VICTORIAN GLASS HANGING T-LIGHT',
#  490455: 'HOT WATER BOTTLE KEEP CALM',
#  492513: 'OVAL  MINI PORTRAIT FRAME',
#  488145: 'SET OF 3 REGENCY CAKE TINS',
#  476763: 'PINK CAT BOWL',
#  479955: nan,
#  479157: 'CARD SUKI BIRTHDAY',
#  471765: 'HANGING METAL STAR LANTERN',
#  358911: nan,
#  452319: 'damages?',
#  493563: 'PLAYING CARDS KEEP CALM & CARRY ON',
#  472017: 'WATERING CAN GARDEN MARKER',
#  452004: 'DOORMAT SPOTTY HOME SWEET HOME',
#  473256: 'MAGIC DRAWING SLATE PURDEY',
#  1732374: nan,
#  477162: nan,
#  466452: 'FOUR HOOK  WHITE LOVEBIRDS',
#  357063: 'BROCADE RING PURSE ',
#  478989: 'SET OF 6 T-LIGHTS SANTA',
#  1765638: 'SET/4 WHITE RETRO STORAGE CUBES ',
#  466137: 'POPCORN HOLDER',
#  489699: "BOX OF 6 MINI 50'S CRACKERS",
#  1787079: nan,
#  472332: 'MINI PAINT SET VINTAGE ',
#  479031: 'SET OF 6 T-LIGHTS CACTI ',
#  462588: nan,
#  483588: nan,
#  461496: 'PACK OF 60 MUSHROOM CAKE CASES',
#  474789: 'PENS ASSORTED SPACEBALL',
#  1733907: nan,
#  471870: nan,
#  439194: 'SET/5 RED SPOTTY LID GLASS BOWLS',
#  1787583: 'wrongly marked carton 22804',
#  489531: 'VINTAGE CHRISTMAS STOCKING ',
#  470631: 'JUMBO SHOPPER VINTAGE RED PAISLEY',
#  473109: 'MAGIC DRAWING SLATE GO TO THE FAIR ',
#  482055: '36 FOIL STAR CAKE CASES ',
#  475734: 'DELUXE SEWING KIT ',
#  461643: 'PACK OF 12 BLUE PAISLEY TISSUES ',
#  469581: 'GLASS JAR DAISY FRESH COTTON WOOL',
#  471891: 'TV DINNER TRAY AIR HOSTESS ',
#  435855: 'BLUE PAISLEY POCKET BOOK',
#  442680: 'SET/20 RED RETROSPOT PAPER NAPKINS ',
#  457989: nan,
#  464898: 'BAKING SET 9 PIECE RETROSPOT ',
#  445473: 'PACK OF 72 SKULL CAKE CASES',
#  481047: 'PACK OF 20 NAPKINS PANTRY DESIGN',
#  474138: 'lost',
#  487326: 'LUNCH BAG APPLE DESIGN',
#  474999: 'SET OF 6 SOLDIER SKITTLES',
#  477855: 'SMALL PURPLE BABUSHKA NOTEBOOK ',
#  463827: 'Amazon',
#  435393: 'GOLD MINI TAPE MEASURE ',
#  457464: nan,
#  445347: 'SKULL AND CROSSBONES  GARLAND ',
#  490245: ' DOLLY GIRL BEAKER',
#  494949: 'TRADTIONAL ALPHABET STAMP SET',
#  463491: 'SMALL WHITE RETROSPOT MUG IN BOX ',
#  482958: 'TRAVEL CARD WALLET KEEP CALM',
#  445410: nan,
#  445536: 'SET 3 RETROSPOT TEA,COFFEE,SUGAR',
#  463386: 'LOVE HEART TRINKET POT',
#  457254: 'DECORATIVE CATS BATHROOM BOTTLE',
#  478317: 'GLASS BELL JAR LARGE',
#  444234: 'RED RETROSPOT OVEN GLOVE ',
#  486024: 'ZINC T-LIGHT HOLDER STARS SMALL',
#  472311: 'PACK OF 12 COLOURED PENCILS',
#  477225: 'ALARM CLOCK BAKELIKE CHOCOLATE',
#  1764672: 'CHARLIE + LOLA RED HOT WATER BOTTLE',
#  1764630: 'ENGLISH ROSE HOT WATER BOTTLE',
#  478464: 'damages',
#  483315: 'CORDIAL GLASS JUG',
#  452130: 'DAIRY MAID TOASTRACK',
#  490476: 'LOVE HOT WATER BOTTLE',
#  484029: 'RECYCLED ACAPULCO MAT RED',
#  470883: 'faulty',
#  999390: 'check',
#  447993: 'CLASSIC WHITE FRAME',
#  451101: 'FAWN BLUE HOT WATER BOTTLE',
#  489006: 'BLUE VINTAGE SPOT BEAKER',
#  488964: nan,
#  435267: 'LUNCH BAG  BLACK SKULL.',
#  461748: 'PACK OF 6 SKULL PAPER PLATES',
#  489720: "GIANT 50'S CHRISTMAS CRACKER",
#  461580: 'PACK OF 12 RED RETROSPOT TISSUES ',
#  486759: "CLOCK MAGNET MUM'S KITCHEN",
#  455322: '?display?',
#  1780905: 'CREAM CLIMBING HYDRANGA ART FLOWER',
#  482916: 'TRAVEL CARD WALLET VINTAGE TICKET',
#  446418: '?',
#  445872: 'STRAWBERRY CERAMIC TRINKET POT',
#  -1: nan,
#  460488: 'JUMBO BAG SCANDINAVIAN PAISLEY',
#  1012074: 'DOORMAT HEARTS',
#  487074: 'GYMKHANNA TREASURE BOOK BOX',
#  1788906: 'BUNNY EGG GARLAND',
#  474474: 'CHRISTMAS GINGHAM TREE',
#  490791: 'SET 36 COLOUR PENCILS SPACEBOY ',
#  1784748: '?',
#  470862: 'TOOTHPASTE TUBE PEN',
#  472269: 'PACK OF 12 TRADITIONAL CRAYONS',
#  459648: 'check',
#  315756: nan,
#  465213: 'ANGEL DECORATION STARS ON DRESS',
#  456036: 'BOYS VINTAGE TIN SEASIDE BUCKET',
#  1501017: nan,
#  446460: 'FIRST AID TIN',
#  459417: 'HOME SWEET HOME MUG',
#  489321: 'GARDENERS KNEELING PAD KEEP CALM ',
#  491190: 'DOLLY GIRL MINI RUCKSACK',
#  486318: 'SET OF 5 LUCKY CAT MAGNETS ',
#  493353: 'VINTAGE DOILY TRAVEL SEWING KIT',
#  465024: 'CHRISTMAS CRAFT LITTLE FRIENDS',
#  452277: '?',
#  467334: 'FELT TOADSTOOL LARGE',
#  473319: 'MINI JIGSAW DOLLY GIRL',
#  435729: 'ASSORTED COLOUR MINI CASES',
#  1734222: '??',
#  998886: 'reverse previous adjustment',
#  459396: 'POTTERING MUG',
#  492849: 'CARD HOLDER LOVE BIRD SMALL',
#  479199: 'BIRTHDAY CARD, RETRO SPOT',
#  1732122: 'WOODEN PICTURE FRAME WHITE FINISH',
#  470064: 'LUNCH BAG PINK POLKADOT',
#  444486: '?',
#  460362: 'UNION STRIPE WITH FRINGE  HAMMOCK',
#  489342: 'KNEELING MAT HOUSEWORK  DESIGN',
#  494970: 'TRADITIONAL PICK UP STICKS GAME ',
#  464919: 'amazon',
#  462483: 'EMPIRE BIRTHDAY CARD',
#  1519371: 'SET/6 PINK  BUTTERFLY T-LIGHTS',
#  1890063: 'ROSE COLOUR PAIR HEART HAIR SLIDES',
#  457590: 'VINTAGE SNAP CARDS',
#  488754: 'STAR T-LIGHT HOLDER WILLIE WINKIE',
#  475104: 'IVORY KITCHEN SCALES',
#  316176: 'EDWARDIAN PARASOL PINK',
#  482349: 'HOMEMADE JAM SCENTED CANDLES',
#  479871: 'SET 20 NAPKINS FAIRY CAKES DESIGN ',
#  470442: 'MAGNETS PACK OF 4 VINTAGE COLLAGE',
#  476868: 'WRAP DOLLY GIRL',
#  744891: 'SET OF 3 BIRD LIGHT PINK FEATHER ',
#  487200: 'mailout ',
#  485100: 'SILVER BELLS TABLE DECORATION',
#  461769: 'PACK OF 20 SKULL PAPER NAPKINS',
#  470022: 'LUNCH BAG SPACEBOY DESIGN ',
#  476637: 'GREEN REGENCY TEACUP AND SAUCER',
#  477267: 'ALARM CLOCK BAKELIKE RED ',
#  464709: 'PARTY CONES CANDY TREE DECORATION',
#  465255: nan,
#  466851: 'JIGSAW TREE WITH BIRDHOUSE',
#  485310: 'PARISIENNE KEY CABINET ',
#  475923: 'JUMBO BAG DOLLY GIRL DESIGN',
#  462630: '??',
#  460530: 'JUMBO STORAGE BAG SKULLS',
#  755391: 'ROSE FOLKART HEART DECORATIONS',
#  469560: 'GLASS JAR ENGLISH CONFECTIONERY',
#  435834: 'Found',
#  340599: 'HOUSE SHAPE PENCIL SHARPENER',
#  1788864: 'SET 4 VALENTINE DECOUPAGE HEART BOX',
#  450030: 'SET/3 RED GINGHAM ROSE STORAGE BOX',
#  473613: 'PLASTERS IN TIN SKULLS',
#  486171: 'ZINC SWEETHEART SOAP DISH',
#  484680: 'RED METAL BOX TOP SECRET',
#  460908: 'SET OF 6 CAKE CHOPSTICKS',
#  474096: 'check',
#  478611: nan,
#  482580: 'PANTRY SCRUBBING BRUSH',
#  464289: 'FULL ENGLISH BREAKFAST PLATE',
#  479640: 'ROUND CAKE TIN VINTAGE RED',
#  468993: 'RETROSPOT PARTY BAG + STICKER SET',
#  468888: 'ROUND SNACK BOXES SET OF 4 FRUITS ',
#  440223: 'APPLE BATH SPONGE',
#  491673: 'DECROTIVEVINTAGE COFFEE GRINDER BOX',
#  494718: 'LANDMARK FRAME LONDON BRIDGE ',
#  458472: 'CHOCOLATE CALCULATOR',
#  468720: 'BIRDS MOBILE VINTAGE DESIGN',
#  489447: 'SET OF 60 PANTRY DESIGN CAKE CASES ',
#  490224: "JUMBO BAG 50'S CHRISTMAS ",
#  449001: 'MINI WOODEN HAPPY BIRTHDAY GARLAND',
#  477309: nan,
#  444654: 'found',
#  476679: 'ROSES REGENCY TEACUP AND SAUCER ',
#  477792: 'SET 7 BABUSHKA NESTING BOXES',
#  462567: 'TEA PARTY BIRTHDAY CARD',
#  467985: 'DECORATION HEN ON NEST, HANGING',
#  482895: 'TRAVEL CARD WALLET SUKI',
#  1774689: nan,
#  435078: 'RED RETROSPOT SHOPPER BAG',
#  466368: 'WOOD STAMP SET THANK YOU',
#  1662360: 'HEART SHAPE WIRELESS DOORBELL',
#  469035: 'HEART DECORATION PAINTED ZINC ',
#  486675: nan,
#  1894200: nan,
#  475881: 'CHARLOTTE BAG DOLLY GIRL DESIGN',
#  448917: 'SMALL CAMPHOR WOOD FIELD  MUSHROOM',
#  1764126: 'MAGIC TREE -PAPER FLOWERS',
#  1785567: nan,
#  465822: 'CAKE STAND VICTORIAN FILIGREE SMALL',
#  474327: 'check',
#  435099: 'WOODLAND CHARLOTTE BAG',
#  1528842: 'Wet pallet-thrown away',
#  488376: 'KIDS CUTLERY SPACEBOY ',
#  479094: 'CARD PARTY GAMES ',
#  1768788: 'HEN HOUSE WITH CHICK STANDING',
#  459354: 'GIN AND TONIC MUG',
#  997563: 'found',
#  477288: 'ALARM CLOCK BAKELIKE PINK',
#  491148: 'WOODLAND MINI RUCKSACK ',
#  456078: 'RED METAL BEACH SPADE ',
#  494907: 'EGG CUP HENRIETTA HEN PINK',
#  466116: 'SMALL HEART MEASURING SPOONS',
#  1788150: nan,
#  483210: 'CIRCUS PARADE BABY GIFT SET',
#  466179: 'FRYING PAN RED POLKADOT ',
#  452088: 'DAIRY MAID TRADITIONAL TEAPOT ',
#  477960: 'TRAY, BREAKFAST IN BED',
#  487998: 'SET OF 4 KNICK KNACK TINS LONDON ',
#  475230: 'DOLLY GIRL LUNCH BOX',
#  482139: 'check',
#  448518: 'TOAST ITS - HAPPY BIRTHDAY',
#  463911: 'EMPIRE TISSUE BOX',
#  1782312: nan,
#  1500639: 'HANGING JAM JAR T-LIGHT HOLDERS',
#  478191: 'CLEAR DRAWER KNOB ACRYLIC EDWARDIAN',
#  462609: 'SPACEBOY BIRTHDAY CARD',
#  212835: 'COLOURING PENCILS BROWN TUBE',
#  485016: 'PETIT TRAY CHIC',
#  477477: 'RIBBON REEL CHRISTMAS PRESENT ',
#  451983: 'DOORMAT FANCY FONT HOME SWEET HOME',
#  495159: 'Sale error',
#  486465: 'LARGE CERAMIC TOP STORAGE JAR',
#  486066: 'TRIPLE HOOK ANTIQUE IVORY ROSE',
#  444318: 'MOODY GIRL DOOR HANGER ',
#  451647: 'ELEPHANT BIRTHDAY CARD ',
#  479304: '3 TIER SWEETHEART GARDEN SHELF',
#  451059: '?',
#  488061: 'TREASURE TIN GYMKHANA DESIGN',
#  494130: 'WALL ART,ONLY ONE PERSON ',
#  484092: 'RECYCLED ACAPULCO MAT TURQUOISE',
#  480165: nan,
#  471786: 'FAIRY TALE COTTAGE NIGHT LIGHT',
#  481425: 'AMAZON',
#  1769859: 'check',
#  468615: '200 RED + WHITE BENDY STRAWS',
#  461475: 'PACK OF 60 DINOSAUR CAKE CASES',
#  481971: '60 CAKE CASES DOLLY GIRL DESIGN',
#  469602: 'GLASS JAR PEACOCK BATH SALTS',
#  490560: 'SET 8 CANDLES VINTAGE DOILEY',
#  442428: 'VINTAGE BILLBOARD LOVE/HATE MUG',
#  489489: 'SET OF 60 I LOVE LONDON CAKE CASES ',
#  466032: nan,
#  445074: 'PINK  HONEYCOMB PAPER FAN',
#  1011864: 'DOORMAT ENGLISH ROSE ',
#  446670: 'ANTIQUE CREAM CUTLERY CUPBOARD',
#  485562: 'PARTY CHARMS 50 PIECES',
#  476805: 'WRAP GREEN PEARS ',
#  477120: nan,
#  443226: 'CREAM SLICE FLANNEL CHOCOLATE SPOT ',
#  478800: 'ANTIQUE TALL SWIRLGLASS TRINKET POT',
#  489468: 'SET OF 60 VINTAGE LEAF CAKE CASES ',
#  1786029: 'Amazon',
#  476133: 'FRENCH GARDEN SIGN BLUE METAL',
#  482643: 'CARD BILLBOARD FONT',
#  447909: 'DINOSAURS  WRITING SET ',
#  474579: 'CHRISTMAS MUSICAL ZINC STAR',
#  1519329: 'SET/6 PURPLE BUTTERFLY T-LIGHTS',
#  440832: 'JAZZ HEARTS PURSE NOTEBOOK',
#  451185: 'RETROSPOT HEART HOT WATER BOTTLE',
#  482160: 'JAM MAKING SET WITH JARS',
#  463806: "PAPER CHAIN KIT 50'S CHRISTMAS ",
#  460005: 'MORE BUTTER METAL SIGN ',
#  786408: 'CERAMIC CAKE DESIGN SPOTTED MUG',
#  470610: 'MONEY BOX HOUSEKEEPING DESIGN',
#  487389: 'mailout',
#  455658: 'MOCK LOBSTER FRIDGE MAGNET',
#  446124: nan,
#  465633: nan,
#  472668: 'DOORSTOP RETROSPOT HEART',
#  339276: nan,
#  489258: 'BUNTING , SPOTTY ',
#  452739: 'STRAWBERRY LUNCH BOX WITH CUTLERY',
#  468405: 'COFFEE MUG PINK PAISLEY DESIGN',
#  443877: nan,
#  1771392: 'Damages/samples',
#  340956: 'KITTY PENCIL ERASERS',
#  444675: nan,
#  480984: 'CALENDAR PAPER CUT DESIGN',
#  463638: nan,
#  487032: 'BUNDLE OF 3 ALPHABET EXERCISE BOOKS',
#  993510: 'SMALL POP BOX FUNKY MONKEY',
#  464079: 'CARAVAN SQUARE TISSUE BOX',
#  453411: 'check',
#  445557: 'RED RETROSPOT ROUND CAKE TINS',
#  476259: 'FRENCH BLUE METAL DOOR SIGN 4',
#  461307: 'PACK OF 12 SKULL TISSUES',
#  1773639: nan,
#  469686: 'DOORMAT AIRMAIL ',
#  457611: 'VINTAGE HEADS AND TAILS CARD GAME ',
#  492114: "3 RAFFIA RIBBONS 50'S CHRISTMAS ",
#  476658: nan,
#  473781: 'WOODEN SCHOOL COLOURING SET',
#  1660071: 'sold as set on dotcom',
#  491232: 'SPACEBOY ROCKET LOLLY MAKERS',
#  445998: 'RED RETROSPOT CUP',
#  467187: 'BUNNY DECORATION MAGIC GARDEN',
#  478737: 'damages',
#  480039: 'EASTER TIN BUNNY BOUQUET',
#  473928: '?? missing',
#  1784811: '60 TEATIME FAIRY CAKE CASES',
#  482706: 'GINGHAM ROSE WRAP',
#  434931: 'lost in space',
#  1734600: 'historic computer difference?....se',
#  479661: 'ROUND CAKE TIN VINTAGE GREEN',
#  478275: nan,
#  1734243: '?',
#  1428: 'ebay',
#  210042: nan,
#  450618: '2 PICTURE BOOK EGGS EASTER BUNNY',
#  454293: 'SUNFLOWER DECORATIVE PARASOL',
#  1783824: 'found',
#  1775256: 'FAIRY CAKES NOTEBOOK A7 SIZE',
#  1764651: 'CHARLIE+LOLA RED HOT WATER BOTTLE ',
#  1782396: 'damaged',
#  463617: '6 RIBBONS RUSTIC CHARM',
#  787059: 'sold as set by dotcom',
#  474348: nan,
#  464961: 'CHRISTMAS CRAFT TREE TOP ANGEL',
#  486507: 'SMALL CERAMIC TOP STORAGE JAR ',
#  491316: 'BUTTERFLY CUSHION COVER',
#  786450: 'CERAMIC CAKE BOWL + HANGING CAKES',
#  1786239: 'FRENCH ENAMEL WATER BASIN',
#  441714: 'REX CASH+CARRY JUMBO SHOPPER',
#  1786491: 'RED CHARLIE+LOLA PERSONAL DOORSIGN',
#  463890: 'PAPER BUNTING RETROSPOT',
#  480942: 'TOTE BAG I LOVE LONDON',
#  474054: 'HEART WOODEN CHRISTMAS DECORATION',
#  463596: '6 RIBBONS EMPIRE  ',
#  486948: 'VINTAGE  2 METER FOLDING RULER',
#  490371: "ROLL WRAP 50'S CHRISTMAS",
#  467208: 'DECORATION  PINK CHICK MAGIC GARDEN',
#  485583: 'COCKTAIL SWORDS 50 PIECES',
#  487368: 'LUNCH BAG VINTAGE LEAF DESIGN',
#  487746: 'FILIGREE HEART DAISY WHITE',
#  491379: 'HOME SWEET HOME HANGING HEART',
#  460551: 'JUMBO STORAGE BAG SUKI',
#  477372: '3D VINTAGE CHRISTMAS STICKERS ',
#  494214: 'STOP FOR TEA WALL ART',
#  487263: 'mailout',
#  449295: nan,
#  468636: '200 BENDY SKULL STRAWS',
#  1789242: 'HANGING WOOD AND FELT HEART',
#  450219: 'BASKET OF TOADSTOOLS',
#  469098: 'STAR DECORATION PAINTED ZINC ',
#  481089: 'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#  358764: 'TRANQUILITY MASALA INCENSE',
#  493437: 'CLASSIC CROME BICYCLE BELL ',
#  786387: 'CERAMIC CAKE DESIGN SPOTTED PLATE',
#  481404: 'sold as set on dotcom',
#  461853: 'FLORAL FOLK STATIONERY SET',
#  455028: 'RED STRIPE CERAMIC DRAWER KNOB',
#  474810: 'PENS ASSORTED FUNNY FACE',
#  475902: 'LUNCH BAG DOLLY GIRL DESIGN',
#  1784937: '?',
#  1734138: 'KITCHEN METAL SIGN',
#  473571: 'PLASTERS IN TIN SPACEBOY',
#  1732206: '3 DRAWER ANTIQUE WHITE WOOD CABINET',
#  464310: 'BIRD HOUSE HOT WATER BOTTLE',
#  1765617: 'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
#  475083: 'BOX OF VINTAGE JIGSAW BLOCKS ',
#  490434: "6 GIFT TAGS 50'S CHRISTMAS ",
#  1784538: 'HANGING HEART JAR T-LIGHT HOLDER',
#  472542: 'reverse 21/5/10 adjustment',
#  444801: 'dotcom',
#  475986: 'RECIPE BOX PANTRY YELLOW DESIGN',
#  489678: 'BOX OF 6 MINI VINTAGE CRACKERS',
#  488040: 'SET OF 4 KNICK KNACK TINS  DOILEY ',
#  457653: 'check',
#  485772: 'SMALL IVORY HEART WALL ORGANISER',
#  450387: nan,
#  489972: 'IVORY WICKER HEART LARGE',
#  441294: 'check',
#  444549: nan,
#  444612: nan,
#  477603: 'MAKE YOUR OWN FLOWERPOWER CARD KIT',
#  443583: 'SET/10 IVORY POLKADOT PARTY CANDLES',
#  486297: 'check',
#  473676: 'PLASTERS IN TIN CIRCUS PARADE ',
#  485331: 'PARISIENNE SEWING BOX',
#  493626: 'MINI PLAYING CARDS SPACEBOY ',
#  466599: '???lost',
#  459711: nan,
#  487494: 'BELL HEART ANTIQUE GOLD',
#  476238: 'FRENCH BLUE METAL DOOR SIGN 3',
#  440181: 'STRAWBERRY BATH SPONGE ',
#  460236: 'SET 12 RETRO WHITE CHALK STICKS',
#  464373: 'GREY HEART HOT WATER BOTTLE',
#  443415: 'ROSE CARAVAN DOORSTOP',
#  472857: 'CHILDS GARDEN RAKE PINK',
#  463365: 'CHRISTMAS PUDDING TRINKET POT ',
#  482097: 'SET 3 PAPER VINTAGE CHICK PAPER EGG',
#  459480: 'RED RETROSPOT TAPE',
#  486108: 'MINITURE ANTIQUE ROSE HOOK IVORY',
#  465990: 'LOCAL CAFE MUG',
#  360465: nan,
#  471072: 'WATERING CAN PINK BUNNY',
#  464499: 'PEACE WOODEN BLOCK LETTERS',
#  490203: '20713',
#  470925: 'ENAMEL COLANDER CREAM',
#  470085: 'JUMBO BAG SPACEBOY DESIGN',
#  489741: 'SMALL WHITE HEART OF WICKER',
#  476532: 'DOORMAT WELCOME TO OUR HOME',
#  451479: 'BLUE POLKADOT WRAP',
#  471849: nan,
#  467124: nan,
#  464331: 'SCOTTIE DOG HOT WATER BOTTLE',
#  474285: 'PACK OF 6 BIRDY GIFT TAGS',
#  1788192: nan,
#  463470: 'SMALL RED RETROSPOT MUG IN BOX ',
#  489930: 'DECORATIVE WICKER HEART MEDIUM',
#  454608: nan,
#  1892436: 'FRUIT SALAD BAG CHARM',
#  488544: 'SET OF 3 WOODEN SLEIGH DECORATIONS',
#  472605: 'MEMO BOARD COTTAGE DESIGN',
#  336945: 'check',
#  1781556: 'ZINC METAL HEART DECORATION',
#  480207: nan,
#  470043: 'LUNCH BAG SUKI  DESIGN ',
#  460068: 'CHOCOLATE THIS WAY METAL SIGN',
#  470316: 'MAGNETS PACK OF 4 RETRO PHOTO',
#  995820: 'ASSORTED COLOUR SUCTION CUP HOOK',
#  478695: nan,
#  473214: 'MAGIC DRAWING SLATE SPACEBOY ',
#  487179: 'JUMBO BAG APPLES',
#  475251: 'CIRCUS PARADE LUNCH BOX ',
#  1779855: 'COLOUR GLASS T-LIGHT HOLDER HANGING',
#  476490: 'DOORMAT HOME SWEET HOME BLUE ',
#  490938: "PACK OF 12 50'S CHRISTMAS TISSUES",
#  454524: 'found',
#  736995: 'BLUE VICTORIAN FABRIC OVAL BOX',
#  1788696: 'SEWING SUSAN 21 NEEDLE SET',
#  473802: 'MONSTERS STENCIL CRAFT',
#  464394: nan,
#  487893: 'WRAP POPPIES  DESIGN',
#  478905: 'BLUE DRAWER KNOB ACRYLIC EDWARDIAN',
#  481278: 'HERB MARKER PARSLEY',
#  456561: 'COSY SLIPPER SHOES LARGE GREEN',
#  467376: 'FELT FARM ANIMAL CHICKEN',
#  477414: 'amazon sales',
#  472353: 'PAINT YOUR OWN CANVAS SET',
#  1722021: 'SILVER RECORD COVER FRAME',
#  468342: 'COFFEE MUG PEARS  DESIGN',
#  484071: 'RECYCLED ACAPULCO MAT BLUE',
#  463428: 'BLACK PIRATE TREASURE CHEST',
#  445326: 'STRAWBERRY HONEYCOMB  GARLAND ',
#  472731: 'RETROSPOT BABUSHKA DOORSTOP',
#  455091: 'RED SPOT CERAMIC DRAWER KNOB',
#  470106: 'JUMBO BAG PINK POLKADOT',
#  489783: 'WHITE WICKER STAR ',
#  490350: 'ROLL WRAP VINTAGE SPOT ',
#  480690: 'NOVELTY BISCUITS CAKE STAND 3 TIER',
#  472395: 'SET OF 2 ROUND TINS CAMEMBERT ',
#  473277: 'MAGIC DRAWING SLATE DINOSAUR',
#  488103: 'SET OF TEA COFFEE SUGAR TINS PANTRY',
#  1734180: 'BATHROOM METAL SIGN',
#  478758: 'ANTIQUE GLASS DRESSING TABLE POT',
#  483000: 'TRAVEL CARD WALLET TRANSPORT',
#  444444: 'HOME SWEET HOME METAL SIGN ',
#  446481: 'GREEN GOOSE FEATHER CHRISTMAS TREE ',
#  486633: 'REGENCY TEAPOT ROSES ',
#  456876: 'BATH BUILDING BLOCK WORD',
#  444381: nan,
#  440391: 'PINK BLUE FELT CRAFT TRINKET BOX',
#  477645: "POPPY'S PLAYHOUSE BEDROOM ",
#  489300: 'GARDENERS KNEELING PAD CUP OF TEA ',
#  1787394: 'RED ENCHANTED FOREST PLACEMAT',
#  437430: 'SILVER PHOTO FRAME',
#  448938: 'SMALL TALL CAMPHOR WOOD TOADSTOOL',
#  1011948: 'DOORMAT WELCOME PUPPIES',
#  476784: 'WRAP RED APPLES ',
#  488607: 'SET OF 4 SANTA PLACE SETTINGS',
#  481698: 'CUPCAKE LACE PAPER SET 6',
#  468363: 'COFFEE MUG APPLES DESIGN',
#  463344: 'PINK DOUGHNUT TRINKET POT ',
#  466410: 'WOOD STAMP SET BEST WISHES',
#  840021: 'check',
#  1665741: nan,
#  460467: nan,
#  1788423: 'WHITE BAROQUE WALL CLOCK ',
#  477897: 'LARGE RED BABUSHKA NOTEBOOK ',
#  787500: 'TEA TIME TEAPOT IN GIFT BOX',
#  493878: 'EMBROIDERED RIBBON REEL RACHEL ',
#  451626: 'FANCY FONT BIRTHDAY CARD, ',
#  482979: 'TRAVEL CARD WALLET RETRO PETALS',
#  315819: 'SANDALWOOD FAN',
#  1890294: 'SILVER AND BLACK ORBIT NECKLACE',
#  475566: 'CERAMIC STRAWBERRY CAKE MONEY BANK',
#  491442: 'HOME SWEEET HOME 3 PEG HANGER ',
#  474117: 'check',
#  452676: 'CERAMIC STRAWBERRY MONEY BOX',
#  483252: 'GLASS APOTHECARY BOTTLE PERFUME',
#  1780716: nan,
#  443541: 'SET/10 RED POLKADOT PARTY CANDLES',
#  448980: 'WOODEN HAPPY BIRTHDAY GARLAND',
#  471807: nan,
#  476091: 'FRENCH LAUNDRY SIGN BLUE METAL',
#  460194: 'BLUE HARMONICA IN BOX ',
#  480963: 'CALENDAR FAMILY FAVOURITES',
#  464457: 'check',
#  487872: 'WRAP VINTAGE PETALS  DESIGN',
#  450555: 'PAINTED YELLOW WOODEN DAISY',
#  471954: 'SPACEBOY TV DINNER TRAY',
#  452718: 'SKULL LUNCH BOX WITH CUTLERY ',
#  475545: 'CERAMIC HEART FAIRY CAKE MONEY BANK',
#  1776201: 'check',
#  460593: 'PINK VINTAGE PAISLEY PICNIC BAG',
#  446082: 'RED RETROSPOT PLATE ',
#  464604: 'SET OF 2 TEA TOWELS PING MICROWAVE',
#  446040: 'BLUE POLKADOT CUP',
#  1764609: nan,
#  471597: 'NATURAL SLATE HEART CHALKBOARD ',
#  471261: 'GROW YOUR OWN BASIL IN ENAMEL MUG',
#  472248: 'NATURAL SLATE RECTANGLE CHALKBOARD',
#  462987: 'EMPIRE GIFT WRAP',
#  490266: 'SPACEBOY BEAKER',
#  485520: 'PACK OF 6 SMALL FRUIT STRAWS',
#  469896: 'AIRLINE BAG VINTAGE JET SET WHITE',
#  478296: 'CAKESTAND, 3 TIER, LOVEHEART',
#  471660: 'EMBOSSED GLASS TEALIGHT HOLDER',
#  471219: '6 ROCKET BALLOONS ',
#  467796: nan,
#  486339: nan,
#  469917: 'BOTTLE BAG RETROSPOT ',
#  486591: 'REGENCY TEA PLATE GREEN ',
#  455259: 'SKULLS  STICKERS',
#  1776789: 'damages',
#  479535: 'HOT WATER BOTTLE I AM SO POORLY',
#  487620: 'REINDEER HEART DECORATION GOLD',
#  487662: 'CHRISTMAS TREE HANGING GOLD',
#  435246: 'LUNCH BAG WOODLAND',
#  434259: 'EDWARDIAN PARASOL RED',
#  481488: 'YELLOW GIANT GARDEN THERMOMETER',
#  489048: 'check',
#  440601: '12 PENCILS TALL TUBE WOODLAND',
#  460635: 'SUKI  SHOULDER BAG',
#  489027: 'RED VINTAGE SPOT BEAKER',
#  478716: 'Not rcvd in 10/11/2010 delivery',
#  440454: '12 PENCILS SMALL TUBE SKULL',
#  434364: 'STRAWBERRY DREAM CHILDS UMBRELLA',
#  755013: 'FOLKART STAR CHRISTMAS DECORATIONS',
#  467061: 'GARLAND WOODEN HAPPY EASTER',
#  475692: 'check',
#  755181: 'FOLKART ZINC HEART CHRISTMAS DEC',
#  482265: '3 TRADITIONAL COOKIE CUTTERS  SET',
#  340935: 'RECYCLED PENCIL WITH RABBIT ERASER',
#  478884: 'Wrongly mrked had 85123a in box',
#  451164: nan,
#  477330: 'ALARM CLOCK BAKELIKE IVORY',
#  340977: 'SLEEPING CAT ERASERS',
#  1782459: 'damaged',
#  1776180: 'MOUSE TOY WITH PINK T-SHIRT',
#  492996: 'WOODLAND LARGE RED FELT HEART',
#  441315: 'DARK BIRD HOUSE TREE DECORATION',
#  476889: 'WRAP WEDDING DAY',
#  494781: 'SET OF 6 RIBBONS PARTY',
#  452781: 'DINOSAUR LUNCH BOX WITH CUTLERY',
#  454125: 'VINTAGE UNION JACK APRON',
#  315924: nan,
#  470820: 'LIPSTICK PEN BABY PINK',
#  473550: 'HOLIDAY FUN LUDO',
#  494067: 'ANIMALS AND NATURE WALL ART',
#  482181: 'JAM MAKING SET PRINTED',
#  1787709: 'BEADED CRYSTAL HEART BLUE SMALL',
#  470757: 'PACK OF 60 SPACEBOY CAKE CASES',
#  484344: 'Crushed',
#  456729: 'LARGE RED RETROSPOT WINDMILL',
#  461706: 'PACK OF 12 PINK POLKADOT TISSUES',
#  446712: '?',
#  1782480: nan,
#  466011: 'IVORY DINER WALL CLOCK',
#  491757: 'BATHROOM HOOK',
#  470358: 'MAGNETS PACK OF 4 SWALLOWS',
#  471345: nan,
#  462672: 'BOTANICAL LILY GREETING CARD',
#  489174: 'SET OF 6 SNACK LOAF BAKING CASES',
#  1788738: 'VICTORIAN SEWING KIT',
#  1785294: 'BLACK/BLUE POLKADOT UMBRELLA',
#  463239: 'CERAMIC STRAWBERRY DESIGN MUG',
#  440643: '12 PENCILS TALL TUBE RED RETROSPOT',
#  474537: 'CHRISTMAS MUSICAL ZINC HEART ',
#  481845: 'sold as set on dotcom',
#  1775571: 'CROCHET DOG KEYRING',
#  487767: 'FILIGREE HEART BUTTERFLY WHITE ',
#  449085: 'IVORY HANGING DECORATION  HEART',
#  1720992: nan,
#  465087: 'check',
#  484638: 'ICE CREAM PEN LIP GLOSS ',
#  490707: 'SET 12 COLOUR PENCILS SPACEBOY ',
#  443310: nan,
#  477939: 'found',
#  469980: 'TOY TIDY SPACEBOY  ',
#  468741: 'BIRD DECORATION RED RETROSPOT',
#  444927: nan,
#  1011927: 'DOORMAT NEW ENGLAND',
#  455763: 'BAG 125g SWIRLY MARBLES',
#  440433: nan,
#  487242: 'mailout',
#  472710: 'GINGHAM BABUSHKA DOORSTOP',
#  459900: 'KEY FOB , SHED',
#  480837: 'OVEN MITT APPLES DESIGN',
#  1894494: 'LETTER "U" BLING KEY RING',
#  468846: 'ROUND SNACK BOXES SET OF4 WOODLAND ',
#  474516: 'CHRISTMAS STAR WISH LIST CHALKBOARD',
#  1785420: 'ROUND PINK HEART MIRROR',
#  487473: 'STAR WREATH DECORATION WITH BELL',
#  468489: 'TEA COSY RED  STRIPE',
#  493647: 'MINI PLAYING CARDS BUFFALO BILL ',
#  485352: 'PARISIENNE CURIO CABINET',
#  494235: 'BICYCLE SAFTEY WALL ART',
#  474453: 'CHRISTMAS GINGHAM STAR',
#  470778: '10 COLOUR SPACEBOY PEN',
#  483126: 'TRAVEL CARD WALLET FLOWER MEADOW',
#  481782: 'CHRISTMAS LIGHTS 10 SANTAS ',
#  490665: 'SET 12 COLOUR PENCILS LOVE LONDON',
#  1788843: 'CHARLIE & LOLA WASTEPAPER BIN FLORA',
#  486234: 'SET OF 4 JAM JAR MAGNETS',
#  472185: 'SET OF 2 WOODEN MARKET CRATES',
#  480333: 'NUMBER TILE COTTAGE GARDEN 5',
#  465150: '3 STRIPEY MICE FELTCRAFT',
#  476574: 'WICKER STAR ',
#  476553: 'GROW A FLYTRAP OR SUNFLOWER IN TIN',
#  445620: 'SET/4 BADGES DOGS',
#  469665: 'DOORMAT RESPECTABLE HOUSE',
#  471051: 'WATERING CAN BLUE ELEPHANT',
#  476175: 'FRENCH KITCHEN SIGN BLUE METAL',
#  486822: 'TOILET SIGN OCCUPIED OR VACANT',
#  460026: 'PHARMACIE FIRST AID TIN',
#  456834: 'HOME BUILDING BLOCK WORD',
#  494025: 'BUFFALO BILL WALL ART ',
#  459438: 'PACK OF 6 SANDCASTLE FLAGS ASSORTED',
#  473865: 'FELTCRAFT HAIRBANDS PINK AND WHITE ',
#  478086: 'PHOTO FRAME CORNICE',
#  340998: 'PARTY TIME PENCIL ERASERS',
#  495201: 'JUMBO BAG PAISLEY PARK',
#  481992: '72 CAKE CASES VINTAGE CHRISTMAS',
#  462651: 'BOTANICAL LAVENDER BIRTHDAY CARD',
#  467943: '6 EGG HOUSE PAINTED WOOD',
#  1894368: 'PAIR OF PINK FLOWER CLUSTER SLIDE',
#  477771: 'FELTCRAFT PRINCESS OLIVIA DOLL',
#  471996: 'EMPIRE UNION JACK TV DINNER TRAY',
#  434154: 'GREEN POLKADOT BOWL',
#  466053: 'RED DINER WALL CLOCK',
#  465759: 'SET 10 LIGHTS NIGHT OWL',
#  754215: 'damaged',
#  449463: 'BLUE EGG  SPOON',
#  480900: ' SET 2 TEA TOWELS I LOVE LONDON ',
#  484176: 'CRYSTAL CHANDELIER T-LIGHT HOLDER',
#  1783929: 'SILVER HANGING T-LIGHT HOLDER',
#  463323: 'CERAMIC BOWL WITH STRAWBERRY DESIGN',
#  1732164: 'WOOD BLACK BOARD ANT WHITE FINISH',
#  473718: 'CLOTHES PEGS RETROSPOT PACK 24 ',
#  479115: 'CARD PSYCHEDELIC APPLES',
#  449190: 'FILIGRIS HEART WITH BUTTERFLY',
#  472521: 'incorrectly put back into stock',
#  481131: 'PAPER CHAIN KIT LONDON',
#  480123: nan,
#  433818: nan,
#  482622: 'PANTRY PASTRY BRUSH',
#  489846: 'HANGING MINI COLOURED BOTTLES',
#  1783866: 'ANTIQUE SILVER TEA GLASS ETCHED',
#  460509: 'JUMBO BAG PINK VINTAGE PAISLEY',
#  1780632: 'ENCHANTED BIRD COATHANGER 5 HOOK',
#  486423: 'REGENCY SUGAR TONGS',
#  481551: 'BAKING MOULD HEART WHITE CHOCOLATE',
#  1011885: '?',
#  483273: 'GLASS APOTHECARY BOTTLE TONIC',
#  1789767: 'SET OF 6 3D KIT CARDS FOR KIDS',
#  477351: '3D CHRISTMAS STAMPS STICKERS ',
#  463680: nan,
#  440349: 'RED FLORAL FELTCRAFT SHOULDER BAG',
#  442638: nan,
#  469308: 'TEA BAG PLATE RED RETROSPOT',
#  484554: 'EMBOSSED HEART TRINKET BOX',
#  474033: 'STAR WOODEN CHRISTMAS DECORATION',
#  469518: 'KINGS CHOICE TEA CADDY ',
#  460152: 'VINTAGE SNAKES & LADDERS',
#  468867: 'ROUND SNACK BOXES SET OF 4 SKULLS',
#  486801: 'BULL DOG BOTTLE TOP WALL CLOCK',
#  480438: 'NUMBER TILE COTTAGE GARDEN No',
#  442281: 'PARTY INVITES FOOTBALL',
#  461790: 'MODERN FLORAL STATIONERY SET',
#  1785756: nan,
#  1775235: nan,
#  491904: 'GINGHAM RECIPE BOOK BOX',
#  444255: 'RED RETROSPOT PEG BAG',
#  483693: 'DRAWER KNOB CERAMIC RED',
#  492177: "GIFT BAG LARGE 50'S CHRISTMAS",
#  480858: 'CHILDRENS APRON APPLES DESIGN',
#  481467: 'damaged',
#  494466: 'WRAP PAISLEY PARK ',
#  465801: 'check',
#  1783950: 'ASSORTED COLOUR T-LIGHT HOLDER',
#  477687: "POPPY'S PLAYHOUSE BATHROOM",
#  477708: "POPPY'S PLAYHOUSE KITCHEN",
#  471828: 'BABUSHKA LIGHTS STRING OF 10',
#  445578: 'RED SPOTTY BISCUIT TIN',
#  460614: 'SKULL SHOULDER BAG',
#  1787772: nan,
#  467733: 'FELTCRAFT DOLL MOLLY',
#  468531: 'OFFICE MUG WARMER BLACK+SILVER ',
#  462945: 'SPACEBOY GIFT WRAP',
#  440664: 'damaged',
#  482202: 'JAM JAR WITH PINK LID',
#  447027: 'SCENTED VELVET LOUNGE CANDLE ',
#  484008: 'SET OF 10 LANTERNS FAIRY LIGHT STAR',
#  477183: 'SET OF 6 HERB TINS SKETCHBOOK',
#  490182: 'MINT DINER CLOCK',
#  461517: 'PACK OF 60 PINK PAISLEY CAKE CASES',
#  454272: nan,
#  484764: 'for online retail orders',
#  487284: 'CHARLOTTE BAG APPLES DESIGN',
#  465276: 'HEART DECORATION WITH PEARLS ',
#  450870: 'FLOWER VINE RAFFIA FOOD COVER',
#  449778: 'STARFISH SOAP DISH',
#  433713: 'CHERRY BLOSSOM LUGGAGE TAG',
#  478422: 'SET 3 WICKER STORAGE BASKETS ',
#  460866: 'PARTY TIME DESIGN FLANNEL',
#  454944: nan,
#  1890777: 'TINY CRYSTAL BRACELET RED',
#  463512: 'RED RETROSPOT TEA CUP AND SAUCER ',
#  446019: 'PINK  POLKADOT CUP',
#  316218: 'wet/rusty',
#  998907: 'TEA TIME KITCHEN APRON',
#  1782417: '?',
#  488355: 'CHILDRENS CUTLERY CIRCUS PARADE',
#  1789284: 'lost??',
#  458493: 'damages',
#  456393: 'RED HANGING HEART T-LIGHT HOLDER',
#  490413: '6 GIFT TAGS VINTAGE CHRISTMAS ',
#  487557: 'LAUREL HEART ANTIQUE SILVER',
#  456855: 'LOVE BUILDING BLOCK WORD',
#  486570: 'REGENCY TEA PLATE ROSES ',
#  999474: 'SCOTTIES DESIGN WASHBAG',
#  453789: nan,
#  440916: 'JAZZ HEARTS ADDRESS BOOK',
#  475041: 'TRADITIONAL KNITTING NANCY',
#  481383: 'sold as set on dotcom',
#  434385: 'DOORMAT RED RETROSPOT',
#  475167: nan,
#  443058: 'damages?',
#  467481: 'FELT EGG COSY WHITE RABBIT ',
#  470673: 'METAL SIGN TAKE IT OR LEAVE IT ',
#  435183: 'STRAWBERRY CHARLOTTE BAG',
#  456666: 'SMALL RED RETROSPOT WINDMILL',
#  485478: 'check',
#  464583: 'PING MICROWAVE APRON',
#  481761: 'CHRISTMAS LIGHTS 10 REINDEER',
#  1774710: 'SET OF 4 POLKADOT COASTERS',
#  435750: 'RED RETROSPOT MINI CASES',
#  473760: 'TRADITIONAL MODELLING CLAY',
#  470967: 'damages',
#  483105: 'printing smudges/thrown away',
#  475377: 'damages',
#  999180: 'TEA TIME DES TEA COSY',
#  469119: 'check',
#  479472: 'BROCANTE SHELF WITH HOOKS',
#  477498: 'RIBBON REEL SNOWY VILLAGE',
#  470988: 'ENAMEL FIRE BUCKET CREAM',
#  440559: '36 PENCILS TUBE RED RETROSPOT',
#  465927: 'GREEN CHRISTMAS TREE CARD HOLDER',
#  483168: 'DOLLY GIRL BABY GIFT SET',
#  467838: 'OVERNIGHT BAG VINTAGE ROSE PAISLEY',
#  474495: 'check',
#  1514751: 'COLUMBIAN CANDLE RECTANGLE',
#  1783446: 'LA PALMIERA TILE COASTER',
#  471303: nan,
#  480186: nan,
#  441378: 'damaged',
#  486969: 'SET OF 12 FORK CANDLES',
#  455070: nan,
#  485793: 'LARGE IVORY HEART WALL ORGANISER',
#  442890: 'WET/MOULDY',
#  490161: 'PINK DINER WALL CLOCK',
#  1891974: 'NECKLACE+BRACELET SET FRUIT SALAD ',
#  453138: nan,
#  1774899: 'TOMATO CHARLIE+LOLA COASTER SET',
#  449568: 'SPOTTY PINK DUCK DOORSTOP',
#  465528: nan,
#  452235: nan,
#  474600: 'CHRISTMAS RETROSPOT STAR WOOD',
#  465171: 'PLACE SETTING WHITE HEART',
#  463764: nan,
#  460047: nan,
#  493668: 'MINI PLAYING CARDS DOLLY GIRL ',
#  455175: 'BUTTERFLIES STICKERS',
#  492219: 'HAND WARMER RED LOVE HEART',
#  490098: 'EGG FRYING PAN RED ',
#  755370: nan,
#  441819: 'RED RETROSPOT SHOPPING BAG',
#  478107: 'TRIPLE PHOTO FRAME CORNICE ',
#  447111: 'SMALL POLKADOT CHOCOLATE GIFT BAG ',
#  473634: 'PLASTERS IN TIN WOODLAND ANIMALS',
#  1786638: 'missing',
#  452424: 'SKULLS  WATER TRANSFER TATTOOS ',
#  479766: 'BREAD BIN DINER STYLE RED ',
#  784140: 'sold as set on dotcom',
#  467691: 'check',
#  492051: 'NATURAL HANGING QUILTED HEARTS ',
#  482223: 'JAM JAR WITH BLUE LID',
#  473844: 'ALPHABET STENCIL CRAFT',
#  493311: 'VINTAGE JINGLE BELLS HEART',
#  475524: 'CERAMIC CHERRY CAKE MONEY BANK',
#  474957: 'mouldy, thrown away.',
#  1785840: nan,
#  457506: 'check',
#  484659: ' TOADSTOOL BEDSIDE LIGHT ',
#  489867: 'HANGING CLEAR MINI BOTTLE',
#  476154: 'FRENCH TOILET SIGN BLUE METAL',
#  464982: 'check',
#  472101: 'wet boxes',
#  493374: 'VINTAGE DOILY DELUXE SEWING KIT ',
#  469707: 'CHILDRENS APRON SPACEBOY DESIGN',
#  475209: 'SPACEBOY LUNCH BOX ',
#  479724: 'VINTAGE CREAM DOG FOOD CONTAINER',
#  472920: nan,
#  474159: 'dotcom',
#  467145: nan,
#  440685: 'HEART CALCULATOR',
#  487347: 'LUNCH BAG ALPHABET DESIGN',
#  434952: 'JUMBO BAG WOODLAND ANIMALS',
#  484449: 'EDWARDIAN PHOTO FRAME',
#  477834: 'SMALL RED BABUSHKA NOTEBOOK ',
#  451584: nan,
#  1771980: 'SET OF 3 BUTTERFLY COOKIE CUTTERS',
#  462924: nan,
#  486717: 'TREASURE ISLAND BOOK BOX',
#  471744: 'HANGING METAL HEART LANTERN',
#  477435: 'RIBBON REEL SOCKS AND MITTENS',
#  464352: 'CHOCOLATE HOT WATER BOTTLE',
#  477666: "POPPY'S PLAYHOUSE LIVINGROOM ",
#  446439: nan,
#  459165: nan,
#  1783887: 'ANTIQUE SILVER TEA GLASS ENGRAVED',
#  464226: 'MIRROR MOSAIC HURRICANE LAMP ',
#  487221: 'JUMBO BAG ALPHABET',
#  449862: nan,
#  480816: 'PEG BAG APPLE DESIGN',
#  479010: 'check',
#  451668: 'VINTAGE KID DOLLY CARD ',
#  475419: 'SET OF 4 NAPKIN CHARMS HEARTS',
#  497301: 'LUNCH BAG RED VINTAGE DOILY',
#  476994: 'CARD BIRTHDAY COWBOY',
#  483945: 'PAPER LANTERN 5 POINT STAR MOON 30',
#  462777: 'ROBOT BIRTHDAY CARD',
#  459564: 'CAKES AND BOWS GIFT  TAPE',
#  481614: 'BAKING MOULD EASTER EGG WHITE CHOC',
#  1785672: nan,
#  465192: 'check',
#  466767: 'HANGING HEART MIRROR DECORATION ',
#  457401: 'damages?',
#  486549: 'smashed',
#  784770: nan,
#  464415: 'METAL SIGN EMPIRE TEA',
#  469539: 'GLASS JAR KINGS CHOICE',
#  449043: 'PACK OF 12 STICKY BUNNIES',
#  447594: 'SMALL GLASS HEART TRINKET POT',
#  1894305: 'LARGE CRYSTAL DIAMANTE HAIRSLIDE',
#  477015: 'CARD WEDDING DAY',
#  1768578: nan,
#  475713: 'BUTTON BOX ',
#  457527: 'RAIN PONCHO RETROSPOT',
#  479052: '?',
#  472374: 'EMERGENCY FIRST AID TIN ',
#  481110: 'PAPER CHAIN KIT VINTAGE CHRISTMAS',
#  357252: nan,
#  1783509: 'code mix up? 84930',
#  476406: 'FRENCH BLUE METAL DOOR SIGN No',
#  432936: 'CHERRY BLOSSOM PASSPORT COVER',
#  478023: 'KEY CABINET MA CAMPAGNE',
#  494634: 'LANDMARK FRAME OXFORD STREET',
#  494382: "70'S ALPHABET WALL ART",
#  449988: 'SET3 BOOK BOX GREEN GINGHAM FLOWER ',
#  461685: 'PACK OF 12 HEARTS DESIGN TISSUES ',
#  1783299: nan,
#  466788: 'BUNNY WOODEN PAINTED WITH BIRD ',
#  459207: 'PINK UNION JACK  LUGGAGE TAG',
#  444087: 'found',
#  456435: 'damages',
#  452214: 'DAIRY MAID LARGE MILK JUG',
#  752178: nan,
#  474705: 'WOODEN CROQUET GARDEN SET',
#  433692: 'check',
#  1527561: 'GRAND CHOCOLATECANDLE',
#  476910: 'WRAP I LOVE LONDON ',
#  479745: 'VINTAGE CREAM CAT FOOD CONTAINER',
#  470799: 'LIPSTICK PEN RED',
#  493689: 'MINI PLAYING CARDS FUN FAIR ',
#  1071294: 'FEATHER PEN,LIGHT PINK',
#  455049: 'BLUE STRIPE CERAMIC DRAWER KNOB',
#  448959: 'CAMPHOR WOOD PORTOBELLO MUSHROOM',
#  469455: 'test',
#  494046: 'DOG LICENCE WALL ART',
#  482244: '3 PIECE SPACEBOY COOKIE CUTTER SET',
#  475860: 'DOORMAT I LOVE LONDON',
#  482286: nan,
#  441252: 'ANTIQUE ALL GLASS CANDLESTICK',
#  1891239: 'DIAMANTE HAIR GRIP PACK/2 BLACK DIA',
#  840336: 'damaged stock',
#  479514: 'HAND WARMER BABUSHKA DESIGN',
#  459270: nan,
#  482853: 'SET OF 4 PANTRY JELLY MOULDS',
#  473991: 'ROCKING HORSE RED CHRISTMAS ',
#  454041: '?',
#  487956: 'STORAGE TIN VINTAGE DOILEY ',
#  472122: nan,
#  469476: 'CHARLOTTE BAG PINK POLKADOT',
#  468762: 'BIRD DECORATION GREEN POLKADOT',
#  488733: 'HEART T-LIGHT HOLDER WILLIE WINKIE',
#  1778532: 'BOX OF 24 COCKTAIL PARASOLS',
#  434196: 'RED RETROSPOT BOWL',
#  1772526: 'incorrectly made-thrown away.',
#  435771: 'check',
#  492891: 'SIX DRAWER OFFICE TIDY',
#  468237: 'HEART IVORY TRELLIS SMALL',
#  437976: '??',
#  459774: nan,
#  447846: 'AGED GLASS SILVER T-LIGHT HOLDER',
#  445095: nan,
#  456183: 'ALPHABET HEARTS STICKER SHEET',
#  440706: 'BLUE CALCULATOR RULER',
#  464520: 'WELCOME  WOODEN BLOCK LETTERS',
#  489279: 'FOOD COVER WITH BEADS , SET 2 SIZES',
#  483987: 'PAPER LANTERN 5 POINT SEQUIN STAR',
#  475146: 'BLACK KITCHEN SCALES',
#  448728: 'MIRRORED WALL ART LADIES',
#  474180: 'ADVENT CALENDAR GINGHAM SACK',
#  1776516: '??',
#  1785315: 'SET OF 12  VINTAGE POSTCARD SET',
#  379974: nan,
#  447888: 'BALLOONS  WRITING SET ',
#  455448: 'mixed up',
#  472941: nan,
#  486780: "MUM'S KITCHEN CLOCK",
#  1576029: 'LARGE CIRCULAR MIRROR MOBILE',
#  486654: 'REGENCY SUGAR BOWL GREEN',
#  1769271: 'GREETING CARD, STICKY GORDON',
#  432915: 'BLUE POLKADOT PASSPORT COVER',
#  459291: 'SAVE THE PLANET MUG',
#  ...}

# %%
sample_codes = [486654,477246,471576]  
# sample_codes = [1772526,1764609,456330,477792,1787583,1492113]  
# 不存在，應該回傳 "Unknown"
descriptions = {code: find_item_description(code) for code in sample_codes}

for code, desc in descriptions.items():
    print(f"ItemCode: {code} -> Description: {desc}")
# Out:
# ItemCode: 486654 -> Description: Unknown
# ItemCode: 477246 -> Description: Unknown
# ItemCode: 471576 -> Description: Unknown
